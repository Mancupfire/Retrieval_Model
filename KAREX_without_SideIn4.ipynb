# %%
import os
from langchain_community.embeddings import GPT4AllEmbeddings
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS

embeddings = GPT4AllEmbeddings()
index = faiss.IndexFlatL2(len(embeddings.embed_query("hello world")))
vector_store = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={}
)

# %%
import os
import json
import numpy as np
import torch
from torch_geometric.data import Data
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import openai
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key = "",
)

def ask_gpt(messages: list[dict], model="gpt-4o-mini") -> str:
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        max_tokens=512
    )
    return response.choices[0].message.content

# 2) System prompts (in English)
sys_res = (
    "Re-rank the list of restaurants based on the user’s preferences. "
    "Return only the restaurant names, separated by commas."
)

sys_explain = (
    "You are an expert analyst. "
    "Based on the user’s preferences and the ranking you provided, "
    "please give a brief explanation of why you produced that result."
)

sys_key = "Return only the restaurant names, separated by commas."

# %%
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
# Out:
# c:\Users\Nhat Minh\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
with open('edinburgh-keywords_train.json', 'r', encoding="utf-8") as f:
    train_data = json.load(f)

keywords = list(train_data['np2count'].keys())
keyword_set = set(keywords)

def extract_users(info):
    l_user, user2kw = [], []
    for ii in info:
        lus = info[ii]
        for u in lus:
            if u not in l_user:
                l_user.append(u)
                user2kw.append([])
            idx = l_user.index(u)
            user2kw[idx].append(ii)
    return l_user, user2kw

# %%
train_users, train_users2kw = extract_users(train_data['np2users'])

# %%
restaurant_set = set()
listres = []
for kw in train_data['np2rests'].keys():
    listres.extend(train_data['np2rests'][kw].keys())
restaurant_set = set(listres)

keyword_set = list(keyword_set)
restaurant_set = list(restaurant_set)
restaurants = len(listres)
num_keywords = len(keyword_set)
num_restaurants = len(restaurant_set)
a = np.zeros((num_keywords, num_restaurants))

for kw in train_data['np2rests'].keys():
    for res in train_data['np2rests'][kw].keys():
        idx_kw = keyword_set.index(kw)
        idx_res = restaurant_set.index(res)
        a[idx_kw][idx_res] = 1

# %%
keyword_embeddings = model.encode(list(keyword_set))

# %%
# Load dữ liệu test
with open('edinburgh-keywords_test.json', 'r', encoding="utf-8") as r:
    test_data = json.load(r)

user_keywords = list(test_data['np2reviews'].keys())
user_keywords_list = list(user_keywords)

# %%
test_users, test_users2kw = extract_users(test_data['np2users'])
test_keywords = [kw for sublist in test_users2kw for kw in sublist]
test_keyword_embeddings = model.encode(test_keywords)
similarity_scores = cosine_similarity(test_keyword_embeddings, keyword_embeddings)

# %%
filtered_keywords = []
for i, user_kw in enumerate(test_users2kw):
    updated_user_kw = []
    for kw in user_kw:
        if kw not in keyword_set:
            test_idx = test_keywords.index(kw)
            sim_scores = similarity_scores[test_idx]
            best_match_idx = np.argmax(sim_scores)
            best_match_keyword = keyword_set[best_match_idx]
            updated_user_kw.append(best_match_keyword)
        else:
            updated_user_kw.append(kw)
    filtered_keywords.append(updated_user_kw)

# %%
test_users2kw = filtered_keywords

# %%
results = []
for kw in test_users2kw:
    t = np.zeros((1, len(keyword_set)))
    keywords_subset = kw[:10]
    for key in keywords_subset:
        if key in keyword_set:
            idx_kw = keyword_set.index(key)
            t[0][idx_kw] = 1
    R = np.dot(t, a)
    result = np.argsort(R[0])[::-1][:10]
    results.append(result)

# %%
sys_res_en = (
    "Please re-rank the list of restaurants based on the user’s preferences. "
    "Return only the restaurant names, separated by commas."
)

# System prompt for explanation
sys_explain_en = (
    "You are an expert analyst.  "
    "First, give a brief explanation for why your initial ranking is appropriate.  "
    "Then, based on that reasoning, output an improved ranking (just the restaurant names, commas between)."
)

# %%
def GPT_re_rank(user_id, candidate_restaurants, user_keywords):
    prompt_rank = (
        f"The user’s preferences are: {', '.join(user_keywords[:5])}.\n"
        f"Candidate restaurants: {', '.join(candidate_restaurants[:5])}.\n"
        "Please re-rank these restaurants by how well they match the user’s preferences, "
        "and return only the restaurant names, separated by commas."
    )
    messages = [
        {"role": "system", "content": sys_res_en},
        {"role": "user",   "content": prompt_rank},
    ]
    ranked_text = ask_gpt(messages)
    re_ranked = [r.strip() for r in ranked_text.split(",") if r.strip() in candidate_restaurants]
    return re_ranked or candidate_restaurants

# %%
def GPT_explain(user_id, re_ranked_restaurants, user_keywords):
    prompt_explain = (
        f"You have ranked the restaurants as follows: {', '.join(re_ranked_restaurants)}.\n"
        f"The user’s preferences are: {', '.join(user_keywords[:5])}.\n"
        "Please provide a brief explanation of why this ranking is most appropriate."
        "After that, based on your reasoning through explanation to re-rank the restaurants to improve the ranking.\n"
        
    )
    messages = [
        {"role": "system", "content": sys_explain},
        {"role": "user",   "content": prompt_explain},
    ]
    return ask_gpt(messages)

# %%
sys_explain_en = (
    "You are an expert restaurant recommender.  "
    "Given a previous ranking and the user’s preferences, you MUST output **exactly** in this format (no extra text):\n\n"
    "Explanation: <one-sentence overall rationale>\n"
    "Improved ranking: <comma-separated list of restaurant names>\n"
    "Details:\n"
    "- <Restaurant1>: <why it’s placed here>\n"
    "- <Restaurant2>: <why it’s placed here>\n"
    "... (one line per restaurant in the Improved ranking)"
)

def GPT_explain_and_rerank(user_id, re_ranked_restaurants, user_keywords):
    prompt = (
        f"You previously ranked: {', '.join(re_ranked_restaurants[:5])}.\n"
        f"User preferences: {', '.join(user_keywords[:5])}.\n\n"
        "Please follow the format below exactly:\n"
        "Explanation: \n"
        "Improved ranking: \n"
        "Details:\n"
    )
    messages = [
        {"role": "system", "content": sys_explain_en},
        {"role": "user",   "content": prompt},
    ]
    return ask_gpt(messages)

# %%
final_results = []
final_overall_explanations = []
final_detailed_explanations = []

for idx, (user, candidate_indices) in enumerate(zip(test_users, results)):
    candidate_restaurants = [restaurant_set[i] for i in candidate_indices]
    user_kw = test_users2kw[idx]

    first_rank = GPT_re_rank(user, candidate_restaurants, user_kw)

    raw = GPT_explain_and_rerank(user, first_rank, user_kw)
    lines = [l.strip() for l in raw.splitlines() if l.strip()]

    explanation_line = next(l for l in lines if l.lower().startswith("explanation:"))
    overall_expl = explanation_line.split(":", 1)[1].strip()

    ranking_line = next(l for l in lines if l.lower().startswith("improved ranking:"))
    improved_txt = ranking_line.split(":", 1)[1].strip()
    improved_list = [r.strip() for r in improved_txt.split(",") if r.strip()]

    details = {}
    try:
        start = lines.index("Details:") + 1
    except ValueError:
        start = None

    if start is not None:
        for line in lines[start:]:
            if line.startswith("-"):
                rest, reason = line[1:].split(":", 1)
                details[rest.strip()] = reason.strip()

    final_results.append(improved_list)
    final_overall_explanations.append(overall_expl)
    final_detailed_explanations.append(details)

    print(f"User {user} → Improved Ranking: {improved_list}")
    print(f"Overall Explanation: {overall_expl}")
    print("Details:")
    for r, expl in details.items():
        print(f"  - {r}: {expl}")
    print()
# Out:
# User H8mXfh5XgGCqmMLwVH7k5A → Improved Ranking: ['MPzZuWpKpeLBa833zzL9IQ', 'SxT7tgTNxkVuk67XEl7p8g', '2tGFUtUrE0DhwlX59pbArA', 'x0Pk5Uvy0y63FSzcfmxRpQ', 'fY1IkBnRft1KR0O2tqu7pg']
# Overall Explanation: The ranking has been adjusted to prioritize restaurants with strong visual appeal for Instagram, inviting shop fronts, and good social proof from other friends’ recommendations.
# Details:
#   - MPzZuWpKpeLBa833zzL9IQ: Known for aesthetically pleasing presentation, ideal for Instagram posts.
#   - SxT7tgTNxkVuk67XEl7p8g: Has a trendy shop front that is very inviting and popular among friends.
#   - 2tGFUtUrE0DhwlX59pbArA: Good overall experience with some unique features that are nice for groups.
#   - x0Pk5Uvy0y63FSzcfmxRpQ: Offers occasional vouchers, which could be useful but lacks strong Instagram appeal.
#   - fY1IkBnRft1KR0O2tqu7pg: While it's a solid option, it remains lesser-known and does not offer much visual allure.
#
# User QZqj0zcaOXV63mVVVLAhhQ → Improved Ranking: ['vVqxGrqt5ALxQjJGnntpKQ', 'Rwzp59f3Ia-v2V8Ku0zZWQ', 'VEy3-SnvsKgWfGM_b2irbA', 'n2CnBRKK82cWZ9a2OjS2xQ', 'f6SN9YUSpb9AjS4hnFgyxg']
# Overall Explanation: The ranking is adjusted based on the user's preferences for a place with a bar, good items, steak, and desserts.
# Details:
#   - vVqxGrqt5ALxQjJGnntpKQ: This restaurant offers a vibrant bar scene, excellent steak options, and a delectable dessert menu, fitting all user preferences.
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: Known for its quality steaks and a cozy bar atmosphere, it ranks high but slightly below the top option due to less focus on dessert.
#   - VEy3-SnvsKgWfGM_b2irbA: While it provides a nice bar and decent menu items, its steak offerings are not as strong, placing it lower in the ranking.
#   - n2CnBRKK82cWZ9a2OjS2xQ: Features some bar options and a limited steak selection, making it less appealing for the user’s specific desires.
#   - f6SN9YUSpb9AjS4hnFgyxg: Although it may have some items, its overall menu lacks focus on steak and desserts, placing it at the bottom of the list.
#
# User J-NdrqdYuaBZnD8zo9pgjg → Improved Ranking: ['Rwzp59f3Ia-v2V8Ku0zZWQ', 'J9rMt_V1NX49rU3YUjh_7Q', 'I1wArJIYbFl2txUL6unC6A', '_HMiq7vSET4uhNScBdOJnw']
# Overall Explanation: Based on the user's preferences for a place that serves sandwiches for dinner and has a lot of options, the ranking prioritizes establishments that match these criteria.
# Details:
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: It is known for its extensive sandwich menu, making it ideal for dinner and accommodating various preferences.
#   - J9rMt_V1NX49rU3YUjh_7Q: This restaurant offers a good variety of sandwiches and a casual atmosphere for dinner.
#   - I1wArJIYbFl2txUL6unC6A: While it serves sandwiches, its selection is limited compared to the top two.
#   - _HMiq7vSET4uhNScBdOJnw: It has the least focus on sandwiches, making it the least favorable option for the user's preferences.
#
# User XsIVj_AszmnnsykBrKgdHw → Improved Ranking: ['NbQH02mMYJ4r1RqvG2FDBA', 'YnnYwfMEeSru_cJ_qKeofw', 'x44o1_Dw4QsQZRtBJgwZaA', 'wxf-tyEbFaatpJL-43JJpQ', 'hSEGyy0-i1_ZXGIRySbgcg']
# Overall Explanation: The improved ranking prioritizes restaurants that excel in the use of high-quality ingredients, offer a diverse meat selection, and have appealing dessert options to cater to the user's preferences.
# Details:
#   - NbQH02mMYJ4r1RqvG2FDBA: Known for its fresh ingredients and wide variety of meat dishes, along with delicious desserts.
#   - YnnYwfMEeSru_cJ_qKeofw: Offers high-quality meat options and has a strong dessert menu, attracting groups of diners.
#   - x44o1_Dw4QsQZRtBJgwZaA: Provides a decent selection of meats and ingredients, but its dessert options aren't as strong as the top two.
#   - wxf-tyEbFaatpJL-43JJpQ: Features a good variety but lacks the standout meat and dessert offerings found in higher-ranked restaurants.
#   - hSEGyy0-i1_ZXGIRySbgcg: Although it has a unique theme, its ingredients and meat choices don't cater well to the user’s preferences.
#
# User ok0fpB6QHkSUpTQpO3UAfA → Improved Ranking: ['Rwzp59f3Ia-v2V8Ku0zZWQ', 'fqhahiKsc6gPs5Sx4mf9Vg', 'Pv0P0vYFIOlMPPfn18Wc7Q', 'vVqxGrqt5ALxQjJGnntpKQ']
# Overall Explanation: Based on the user's preferences for a dinner outing with friends in a suitable place, the ranking has been adjusted to reflect restaurants that are known for their ambiance and shareable dishes.
# Details:
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: This restaurant offers a vibrant atmosphere and a range of dishes ideal for sharing with friends.
#   - fqhahiKsc6gPs5Sx4mf9Vg: Known for its unique edge in cuisine, this spot is perfect for a fun dinner outing with a group.
#   - Pv0P0vYFIOlMPPfn18Wc7Q: While still a good place, it may not provide the same level of social ambiance as the top choices.
#   - vVqxGrqt5ALxQjJGnntpKQ: This restaurant is solid but does not specialize in shareable dishes, making it less suitable for a friendly dinner.
#
# User gekp2Z5I4vPGf2NeFnZX2A → Improved Ranking: ['3n_2L-oqqw6noFKsb3qmeg', '7LFdimtQU3yrgiKyE53klQ', 'YnnYwfMEeSru_cJ_qKeofw', 'txwpCDw5Utu9WbM0VtYJqg', 'ZhJ59SFPifQiTW0gAddfGw']
# Overall Explanation: Based on the user’s preference for a place with dinner options, a larger quantity, meat dishes, and their previous ranking, the restaurants have been reordered to better align with these criteria.
# Details:
#   - 3n_2L-oqqw6noFKsb3qmeg: This restaurant offers a wide variety of meat dishes suitable for dinner, making it ideal for the user's preferences.
#   - 7LFdimtQU3yrgiKyE53klQ: Known for its hearty portions and diverse meat options, this restaurant ranks highly for providing satisfying dinner experiences.
#   - YnnYwfMEeSru_cJ_qKeofw: Offers a good selection of meat dishes and has a cozy ambiance suitable for dinner, maintaining relevance to the user's needs.
#   - txwpCDw5Utu9WbM0VtYJqg: While it has decent meat offerings, it lacks the extensive quantity preferred by the user for dinner.
#   - ZhJ59SFPifQiTW0gAddfGw: This restaurant is lower on the list due to limited meat options, which may not satisfy the user's request for meat-focused dishes.
#
# User JXrx-kwCSuf1xCkwuv0Nfw → Improved Ranking: ['f6SN9YUSpb9AjS4hnFgyxg', 'l5lEOq47ne-jWKl67VKwZA', 'kA5pZz-koXIlPaDJALDroQ', 'ib_206uhcdzV7lNcCpniXA', 'ko4q1Oj4iWvYSxoamlcEgw']
# Overall Explanation: Based on the user's preferences for a place that highlights truffle oil, fries, sides, and meat, I have reorganized the ranking to prioritize those elements.
# Details:
#   - f6SN9YUSpb9AjS4hnFgyxg: Offers a robust menu featuring truffle oil and fries, making it a top match for meat lovers.
#   - l5lEOq47ne-jWKl67VKwZA: Features a great variety of sides and meat options, with some dishes incorporating truffle oil.
#   - kA5pZz-koXIlPaDJALDroQ: Known for its excellent fries and solid meat choices, although truffle oil is a less frequent feature.
#   - ib_206uhcdzV7lNcCpniXA: While it has good meat options, it lacks side dishes and the signature truffle oil flavor.
#   - ko4q1Oj4iWvYSxoamlcEgw: Primarily focused on unique flavors but doesn't emphasize the requested elements as much as the others.
#
# User FQZZsU3J88IGF8n5e3XYZg → Improved Ranking: ['Rl318hUrGlkPJhMmNNZizQ', 'P-X4kr5pDqXzhPEfa6RsTQ', 'ko4q1Oj4iWvYSxoamlcEgw', '_HMiq7vSET4uhNScBdOJnw', 'I1wArJIYbFl2txUL6unC6A']
# Overall Explanation: Based on the user's preference for a place that offers dinner with a variety of options and dishes, the ranking has been adjusted to highlight restaurants that provide a rich dining experience.
# Details:
#   - Rl318hUrGlkPJhMmNNZizQ: This restaurant features a diverse menu perfect for dinner with a satisfying selection of dishes.
#   - P-X4kr5pDqXzhPEfa6RsTQ: Known for its ample seating and variety, this place can accommodate large groups looking for a fun dinner experience.
#   - ko4q1Oj4iWvYSxoamlcEgw: Offers a good selection of dishes, but doesn't have as much variety as the top two options.
#   - _HMiq7vSET4uhNScBdOJnw: While it has good food, it’s less suited for large gatherings compared to those ranked higher.
#   - I1wArJIYbFl2txUL6unC6A: This option ranks last due to its limited dish variety for dinner and smaller dining space.
#
# User UwWtpjalT2xlJyglRRITug → Improved Ranking: ['BYwoAKKtdSeylSN7QV8oNw', '7LFdimtQU3yrgiKyE53klQ', 'Ku333V1F3_9MVKUJ72_ZBw', '_HMiq7vSET4uhNScBdOJnw', 'x44o1_Dw4QsQZRtBJgwZaA']
# Overall Explanation: The ranking has been adjusted based on the user's preference for dinner places with a varied dish selection and operational hours.
# Details:
#   - BYwoAKKtdSeylSN7QV8oNw: This restaurant is recommended first due to its diverse dinner options and flexible hours.
#   - 7LFdimtQU3yrgiKyE53klQ: Ranked second as it offers a broad range of dishes, making it a great choice for dinner.
#   - Ku333V1F3_9MVKUJ72_ZBw: This one is notable for its operational hours and decent selection, suitable for a casual dinner.
#   - _HMiq7vSET4uhNScBdOJnw: Previously ranked higher, but it has narrower options for dinner, placing it lower.
#   - x44o1_Dw4QsQZRtBJgwZaA: This restaurant offers limited hours and fewer dish varieties, making it the least preferred option.
#
# User uOTNLX7v8MyEikB1yVux3Q → Improved Ranking: ['9R5laAm5Kv4aBLVtH1gVnA', 'txwpCDw5Utu9WbM0VtYJqg', 'I1wArJIYbFl2txUL6unC6A', 'MPzZuWpKpeLBa833zzL9IQ', 'ZSpfF89JnQN6fiS8OhBlZQ']
# Overall Explanation: The improved ranking takes into account the suitability for a group dinner with friends, emphasizing places that offer a diverse menu and a lively atmosphere.
# Details:
#   - 9R5laAm5Kv4aBLVtH1gVnA: This restaurant has a vibrant atmosphere perfect for groups and offers shareable side dishes that friends can enjoy together.
#   - txwpCDw5Utu9WbM0VtYJqg: Known for its delicious sides and group-friendly dining options, this spot allows for a relaxed dinner experience with friends.
#   - I1wArJIYbFl2txUL6unC6A: Offers a good variety of dishes suitable for sharing, making it a great option for friends dining together.
#   - MPzZuWpKpeLBa833zzL9IQ: While a solid choice, it may not cater as well to large groups seeking a lively dining environment.
#   - ZSpfF89JnQN6fiS8OhBlZQ: Although it provides good food, it’s more suited for quieter meals and may lack the group-friendly atmosphere desired for dinner with friends.
#
# User sZ3mumX9WjJqp6qrjPPUBQ → Improved Ranking: ['lE9qVePgvolkhw6C3Cdkeg', 'T7ekp7FiffoWDq53hbZDhg', '_HMiq7vSET4uhNScBdOJnw', 'YkVRDcEa7vZK65u-tlL9tQ']
# Overall Explanation: The ranking has been adjusted to prioritize restaurants that align with the user's preference for places that serve sandwiches and have a bar atmosphere suitable for dinner.
# Details:
#   - lE9qVePgvolkhw6C3Cdkeg: This restaurant has a vibrant bar scene and offers a variety of sandwiches suitable for dinner.
#   - T7ekp7FiffoWDq53hbZDhg: Known for its lively atmosphere and good selection of sandwiches, it's a great choice for a dinner outing.
#   - _HMiq7vSET4uhNScBdOJnw: While it also caters to dinner, it lacks the bar atmosphere that enhances the dining experience.
#   - YkVRDcEa7vZK65u-tlL9tQ: This restaurant is less focused on sandwiches and bar options compared to the others, which may not meet the user's preferences as closely.
#
# User g8VcsAZyMrak3vdrLr3b7w → Improved Ranking: ['JHi4LCxdbpXthg98sQiicQ', 'rXhvV-YyZaJLjgOnz7_jkA', 'tz8VEeIOoM5Cu1NSnC2JIQ', '_HMiq7vSET4uhNScBdOJnw']
# Overall Explanation: The improved ranking prioritizes restaurants that are suitable for a group dinner with friends and offer a meat-focused menu.
# Details:
#   - JHi4LCxdbpXthg98sQiicQ: This restaurant is known for its vibrant atmosphere and hearty meat options, making it ideal for a fun group dinner.
#   - rXhvV-YyZaJLjgOnz7_jkA: Offers a diverse meat menu with ample seating, great for groups looking to enjoy different dishes together.
#   - tz8VEeIOoM5Cu1NSnC2JIQ: Though it has good meat options, its atmosphere is slightly less suited for a lively group dinner compared to the top choices.
#   - _HMiq7vSET4uhNScBdOJnw: While excellent for smaller gatherings, it may not accommodate larger groups as comfortably as the others.
#
# User 1tQfj737uhgdKcQ-5akTdA → Improved Ranking: ['M-PobdAR2gJhPyLR_WzMCQ', 'OExxlOVjUIDh3TFjPzbSDA', '58PYKm0WgNunAzuS4Qu1Zg', '7LFdimtQU3yrgiKyE53klQ', 'qs6gA9Y5sRzpXnm_4QaP0Q']
# Overall Explanation: Given the user’s preferences for a place that can accommodate dinner with a focus on a lot of flavorful dishes and spices, the ranking is adjusted to prioritize those attributes.
# Details:
#   - M-PobdAR2gJhPyLR_WzMCQ: This restaurant is known for its extensive menu rich in exotic spices, making it perfect for a flavorful dinner experience.
#   - OExxlOVjUIDh3TFjPzbSDA: A great option for a sit-down dinner with plenty of space and a diverse selection of dishes that feature bold flavors.
#   - 58PYKm0WgNunAzuS4Qu1Zg: While it offers good dishes, it doesn't provide as much variety in spices as the top two options.
#   - 7LFdimtQU3yrgiKyE53klQ: This restaurant has a cozy atmosphere but is slightly less known for its spiced offerings compared to the higher-ranked options.
#   - qs6gA9Y5sRzpXnm_4QaP0Q: Although it has good food, the lack of a variety of spice-rich dishes makes it less suitable for the user's specific preferences.
#
# User 1UZs_9wFHP4NR_62LwGD6g → Improved Ranking: ['MPzZuWpKpeLBa833zzL9IQ', 'x0Pk5Uvy0y63FSzcfmxRpQ', 'vVqxGrqt5ALxQjJGnntpKQ', '_HMiq7vSET4uhNScBdOJnw', '_7nMWBmfFvk9S3tKG3Ip_g']
# Overall Explanation: Based on the user's preferences for a place that serves sandwiches for dinner and has a lot of options, I have adjusted the ranking to focus on restaurants that align more closely with these criteria.
# Details:
#   - MPzZuWpKpeLBa833zzL9IQ: This restaurant offers a robust selection of sandwiches suitable for dinner and has a welcoming atmosphere.
#   - x0Pk5Uvy0y63FSzcfmxRpQ: Known for its diverse sandwich choices and casual dining experience, making it a great fit for dinner.
#   - vVqxGrqt5ALxQjJGnntpKQ: This spot provides hearty sandwiches and is ideal for dinner with friends or family, though slightly less extensive in variety.
#   - _HMiq7vSET4uhNScBdOJnw: Offers some sandwich options but is more limited in dinner seating, placing it lower in the ranking.
#   - _7nMWBmfFvk9S3tKG3Ip_g: While it may have good sandwiches, it lacks the dinner vibe and variety that the user prefers.
#
# User TUAiW8Lcdla5Ii53kV6RFw → Improved Ranking: ['VEy3-SnvsKgWfGM_b2irbA', 'NbQH02mMYJ4r1RqvG2FDBA', '5LMkTnMXOxlce_LwUNhpCQ', 'J3ijSN86u_Pg42BZjkDM_g', 'EqdAzi9c5xuhxN9brmEaZw.']
# Overall Explanation: The ranking has been adjusted to prioritize venues that are best suited for larger groups and offer dinner options with good sandwich selections.
# Details:
#   - VEy3-SnvsKgWfGM_b2irbA: This place offers a spacious setting perfect for groups and a variety of sandwich options for dinner.
#   - NbQH02mMYJ4r1RqvG2FDBA: Known for its delicious sandwiches and a casual atmosphere suitable for larger gatherings during dinner time.
#   - 5LMkTnMXOxlce_LwUNhpCQ: A popular spot for sandwiches, though slightly smaller in capacity for groups compared to the top two.
#   - J3ijSN86u_Pg42BZjkDM_g: Offers a decent sandwich selection, but lacks the atmosphere for larger groups and is better suited for smaller parties.
#   - EqdAzi9c5xuhxN9brmEaZw: While it has good food, it's not ideal for groups during dinner as space may be limited.
#
# User ZNyfGsIwsedPlpjmoaq3Eg → Improved Ranking: ['Rwzp59f3Ia-v2V8Ku0zZWQ', '5RFNZZvtfF9uHVSUeYwzbQ', 'txwpCDw5Utu9WbM0VtYJqg', 'x44o1_Dw4QsQZRtBJgwZaA']
# Overall Explanation: The user prefers a restaurant that is great for dinner and has Instagram appeal, which aligns with vibrant places suitable for social media sharing and enjoying a bar atmosphere.
# Details:
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: Known for its lively atmosphere and visually appealing dishes, making it perfect for Instagram.
#   - 5RFNZZvtfF9uHVSUeYwzbQ: Offers a great bar selection with a vibrant dinner vibe, appealing to social media enthusiasts.
#   - txwpCDw5Utu9WbM0VtYJqg: Provides a nice dinner experience but lacks the strong Instagram presence compared to the top two.
#   - x44o1_Dw4QsQZRtBJgwZaA: While decent, it ranks lower due to less of an emphasis on bar culture and social media appeal.
#
# User Jd4LuJ2nCNBMayehLhhL4w → Improved Ranking: ['P7-GGakh0UR80xIl93t07Q', 'x44o1_Dw4QsQZRtBJgwZaA', 'VEy3-SnvsKgWfGM_b2irbA', 'NAsglQPCdPMJV_RkHge27A', 'hSEGyy0-i1_ZXGIRySbgcg']
# Overall Explanation: The improved ranking is designed to prioritize restaurants that offer a great steak dinner and delicious desserts in a place suitable for dining with people.
# Details:
#   - P7-GGakh0UR80xIl93t07Q: This restaurant is highly rated for its steak offerings and has a reputation for excellent desserts, making it ideal for dinner with friends or family.
#   - x44o1_Dw4QsQZRtBJgwZaA: This spot provides a fantastic steak experience and is known for its inviting atmosphere, perfect for social gatherings.
#   - VEy3-SnvsKgWfGM_b2irbA: While it does offer great steak options, it's slightly lower on the dessert front but still a solid choice for dinner.
#   - NAsglQPCdPMJV_RkHge27A: This restaurant is known for a good steak but is better suited for smaller groups, which may not align fully with the user's preference for a place to enjoy with more people.
#   - hSEGyy0-i1_ZXGIRySbgcg: Although it has some decent offerings, it ranks lower due to a weaker selection of steak and dessert options compared to the others.
#
# User I0Ml519BP2Ya3-Ec5GgVgA → Improved Ranking: ['MqdAYfl1p_c1144i48k6jw', 'J9rMt_V1NX49rU3YUjh_7Q', 'BYwoAKKtdSeylSN7QV8oNw', 'xpHn6SAJ3xqJGgzZTASrSg', 'vVqxGrqt5ALxQjJGnntpKQ']
# Overall Explanation: The ranking has been adjusted to better align with the user's preference for places that can provide a dining experience rather than just a bar or casual shop setting.
# Details:
#   - MqdAYfl1p_c1144i48k6jw: Ranked highest for its strong focus on dinner offerings, making it ideal for the user's dining preference.
#   - J9rMt_V1NX49rU3YUjh_7Q: Also features robust dinner options, with a good atmosphere for evening meals.
#   - BYwoAKKtdSeylSN7QV8oNw: A decent choice for dinner but slightly less appealing compared to the top two.
#   - xpHn6SAJ3xqJGgzZTASrSg: More of a casual spot, not fully aligning with a sit-down dinner preference.
#   - vVqxGrqt5ALxQjJGnntpKQ: Least relevant for dinner compared to others, more suited for a casual bar experience.
#
# User dpKkBNCSrXgwgqqXd5JqOw → Improved Ranking: ['vVqxGrqt5ALxQjJGnntpKQ', 'ymAw53bQVppVV7T40fNgRw', 'ahlZC7XOKN-XJ7P4sPZrRg', 'bjL1PC2e9dvjBVewmoXYwQ', 'x44o1_Dw4QsQZRtBJgwZaA']
# Overall Explanation: The new ranking focuses on the user’s preferences for amenities such as parking lot, bar availability, flexible hours, and quality of waitstaff.
# Details:
#   - vVqxGrqt5ALxQjJGnntpKQ: This restaurant has excellent parking facilities, a vibrant bar, and highly rated waitstaff.
#   - ymAw53bQVppVV7T40fNgRw: Known for a good selection of drinks at the bar and convenient hours, it ranks high for sociability.
#   - ahlZC7XOKN-XJ7P4sPZrRg: Offers good waiter service and decent parking, but lacks a bar, slightly lowering its rank.
#   - bjL1PC2e9dvjBVewmoXYwQ: While it has favorable hours and service, the absence of a bar and limited parking options affect its appeal.
#   - x44o1_Dw4QsQZRtBJgwZaA: This restaurant has the least appeal based on user preferences due to poor parking and waitstaff reviews.
#
# User cfDwnBtcWi0Bm40lQUHCMg → Improved Ranking: ['ahlZC7XOKN-XJ7P4sPZrRg', 'kA5pZz-koXIlPaDJALDroQ', 'd3vB2tlgTEapMU_kGiXRoQ', 'J9rMt_V1NX49rU3YUjh_7Q', 'pnjp8dim5eVWHIX7oYnEbQ.']
# Overall Explanation: Based on the user's preferences, the improved ranking prioritizes restaurants that excel in ambiance, service quality, and overall food experience.
# Details:
#   - ahlZC7XOKN-XJ7P4sPZrRg: This restaurant is known for its vibrant bar atmosphere and exceptional service, making it a great place for social gatherings.
#   - kA5pZz-koXIlPaDJALDroQ: While also offering a lively setting, it ranks slightly lower due to less focus on food compared to the top choice.
#   - d3vB2tlgTEapMU_kGiXRoQ: Offers good food and service, though the atmosphere isn't as lively as the top two.
#   - J9rMt_V1NX49rU3YUjh_7Q: Generally good service, but the ambiance and crowd are more subdued, making it less appealing for socializing.
#   - pnjp8dim5eVWHIX7oYnEbQ: Although it has decent food, it doesn’t meet the user’s social dynamics as effectively as the others.
#
# User 5GUadxRaN73Jf0fdhaVCFw → Improved Ranking: ['T7ekp7FiffoWDq53hbZDhg', 'AQEEH7JP1DFrvFuMi6TP2Q', 'Pv0P0vYFIOlMPPfn18Wc7Q', 'M3L6py5NM0_WjIT7410M0Q', 'f6SN9YUSpb9AjS4hnFgyxg']
# Overall Explanation: The improved ranking prioritizes places with good service, a bar atmosphere, and a focus on vegetable dishes for dinner.
# Details:
#   - T7ekp7FiffoWDq53hbZDhg: This restaurant stands out for its vibrant bar scene and extensive vegetable-based menu, alongside excellent service.
#   - AQEEH7JP1DFrvFuMi6TP2Q: Known for a cozy atmosphere and solid vegetable options, it has good service but is less lively than the top choice.
#   - Pv0P0vYFIOlMPPfn18Wc7Q: A good dinner spot with decent vegetable selections and acceptable service but lacks a strong bar experience.
#   - M3L6py5NM0_WjIT7410M0Q: While it serves a variety of dishes, the focus on vegetables is weaker, and the bar is less appealing.
#   - f6SN9YUSpb9AjS4hnFgyxg: This place offers a limited selection of vegetables and may not meet the user's preference for a bar setting.
#
# User 2zlt0VIv60yPKkCZ9TuHEg → Improved Ranking: ['CdAmgWWCabZQoYNNWOKcEw', 'ZhJ59SFPifQiTW0gAddfGw', 'fY1IkBnRft1KR0O2tqu7pg', 'KPrdWch1680ihzVe3C-s3w', 'hSEGyy0-i1_ZXGIRySbgcg']
# Overall Explanation: The ranking has been adjusted to prioritize restaurants known for their rice dishes and overall taste, ensuring a satisfying meal experience.
# Details:
#   - CdAmgWWCabZQoYNNWOKcEw: This restaurant excels in flavorful rice dishes and has received high praise for its taste.
#   - ZhJ59SFPifQiTW0gAddfGw: Known for its unique rice combinations and savory meals, this place ranks high for taste.
#   - fY1IkBnRft1KR0O2tqu7pg: While popular, it offers a more limited rice selection compared to the top two.
#   - KPrdWch1680ihzVe3C-s3w: This restaurant has good options but lacks the standout rice dish that others provide.
#   - hSEGyy0-i1_ZXGIRySbgcg: Although well-rated, it prioritizes other cuisines that may not align fully with rice-focused meals.
#
# User 9tliQ8H9xcGN8iVl55nx_g → Improved Ranking: ['Rwzp59f3Ia-v2V8Ku0zZWQ', 'NbQH02mMYJ4r1RqvG2FDBA', 'Pv0P0vYFIOlMPPfn18Wc7Q', 'T7ekp7FiffoWDq53hbZDhg']
# Overall Explanation: The revised ranking prioritizes restaurants with a vibrant atmosphere suitable for dinner and social media appeal, along with ample space for guests.
# Details:
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: This restaurant offers a lively bar scene and is visually appealing for Instagram, making it ideal for your preferences.
#   - NbQH02mMYJ4r1RqvG2FDBA: A great spot for dinner with a robust atmosphere that is also Instagram-friendly, although it might be slightly less spacious than the top choice.
#   - Pv0P0vYFIOlMPPfn18Wc7Q: Offers decent ambiance and is a good choice for dinner but lacks the same level of Instagrammable aspects compared to the top two.
#   - T7ekp7FiffoWDq53hbZDhg: While it has a nice setting, it does not offer the social or bar elements that align with your preferences as effectively as the others.
#
# User YUB60ublKhL0N3sMMYh6aQ → Improved Ranking: ['tRPHSd0ow1hsqMRxyMePeg', 'AQEEH7JP1DFrvFuMi6TP2Q', '0UVlw30JrYGl79rT0XIEmw', 'BYwoAKKtdSeylSN7QV8oNw', 'I1wArJIYbFl2txUL6unC6A']
# Overall Explanation: The ranking has been adjusted to reflect a focus on great ambiance for social gatherings and affordability, aligning better with the user's preferences.
# Details:
#   - tRPHSd0ow1hsqMRxyMePeg: This restaurant offers a vibrant atmosphere and a menu that is both affordable and appealing for food-sharing among friends.
#   - AQEEH7JP1DFrvFuMi6TP2Q: A good place for groups, with reasonably priced options that are sure to please a crowd.
#   - 0UVlw30JrYGl79rT0XIEmw: While still a solid choice, it is a bit pricier compared to the top two, making it less ideal for budget-conscious group outings.
#   - BYwoAKKtdSeylSN7QV8oNw: This place has great food but lacks the lively ambiance that enhances social dining experiences.
#   - I1wArJIYbFl2txUL6unC6A: Although it offers good food, it is more expensive and less suitable for larger groups compared to the others.
#
# User OKbv3KDqjEmYQeADqevsnA → Improved Ranking: ['i5dxKKLe2kJ8WbPUXilPGg', 'ib_206uhcdzV7lNcCpniXA', 'xD3L3JhNxsAfQikOHWHa4w', 'x0Pk5Uvy0y63FSzcfmxRpQ']
# Overall Explanation: The new ranking focuses on restaurants that are more suitable for group dinners with a lot of space and diverse dishes.
# Details:
#   - i5dxKKLe2kJ8WbPUXilPGg: This restaurant offers a spacious dining area ideal for groups and serves a wide variety of dishes perfect for sharing.
#   - ib_206uhcdzV7lNcCpniXA: Known for its ample seating and diverse menu, making it great for friends enjoying dinner together.
#   - xD3L3JhNxsAfQikOHWHa4w: While a bit smaller, it still caters well to groups and has a delightful selection of dishes.
#   - x0Pk5Uvy0y63FSzcfmxRpQ: Though it has some good options, it lacks the space and variety needed for an ideal group dinner setting.
#
# User evIjahgjJHGsuunzD9aT1A → Improved Ranking: ['5RFNZZvtfF9uHVSUeYwzbQ', '5LMkTnMXOxlce_LwUNhpCQ', 'I1wArJIYbFl2txUL6unC6A', '6xx2FpMxjwabEHz_t2MiZg', 'wyDfBs1tYSIiBO7HCPKNTg.']
# Overall Explanation: The ranking has been adjusted to better reflect the user's emphasis on place, service, food, drinks, and menu variety.
# Details:
#   - 5RFNZZvtfF9uHVSUeYwzbQ: This restaurant excels in ambiance and service, providing a great overall dining experience.
#   - 5LMkTnMXOxlce_LwUNhpCQ: Known for its unique menu and quality food, it stands out for a memorable meal.
#   - I1wArJIYbFl2txUL6unC6A: Offers a good variety of drinks, but the food consistency is slightly less reliable.
#   - 6xx2FpMxjwabEHz_t2MiZg: Competitive in service, but lacks the menu innovation and vibe of the top choices.
#   - wyDfBs1tYSIiBO7HCPKNTg: Provides decent food and service, but does not match the overall experience of the others.
#
# User HUodv8WGv4xo7EabaN3dqQ → Improved Ranking: ['txwpCDw5Utu9WbM0VtYJqg', 'Rwzp59f3Ia-v2V8Ku0zZWQ', '_HMiq7vSET4uhNScBdOJnw', 'J9rMt_V1NX49rU3YUjh_7Q', '_7nMWBmfFvk9S3tKG3Ip_g']
# Overall Explanation: Based on the user's preferences for sandwiches, place for dinner, and group dining, I have adjusted the rankings to prioritize restaurants that offer a variety of sandwich options and are suitable for groups.
# Details:
#   - txwpCDw5Utu9WbM0VtYJqg: This restaurant has a comprehensive sandwich menu ideal for groups and offers a vibrant place for dinner.
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: It provides good sandwich options and has a suitable atmosphere for group dining, making it a strong second choice.
#   - _HMiq7vSET4uhNScBdOJnw: Offers a decent variety of sandwiches, but the group accommodations are slightly limited compared to the top two.
#   - J9rMt_V1NX49rU3YUjh_7Q: While it's good for dinner, the sandwich selection is less varied, making it less favorable for the user's preferences.
#   - _7nMWBmfFvk9S3tKG3Ip_g: Although it has good items, it doesn’t specialize in sandwiches or provide the best group dining experience, placing it last.
#
# User 9QDWLRxdU6uOscehvVt6Tw → Improved Ranking: ['vVqxGrqt5ALxQjJGnntpKQ', 'jLcBOqa-UT6qugFgZqjNvA', 'IC15vAUX4EiMlWxxMehohw', 'Rwzp59f3Ia-v2V8Ku0zZWQ']
# Overall Explanation: Based on the user's preferences for place, items, sweetness, dessert, and service, I've reordered the restaurants to better align with these criteria.
# Details:
#   - vVqxGrqt5ALxQjJGnntpKQ: This restaurant excels in providing a great place ambiance and has a diverse menu with a focus on desserts, making it a top choice.
#   - jLcBOqa-UT6qugFgZqjNvA: Known for excellent service and a selection of sweet items, it ranks high for dessert lovers.
#   - IC15vAUX4EiMlWxxMehohw: While it has decent items and service, it lacks the dessert variety to compete with the top two.
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: It falls to the bottom as it doesn't fully meet the user's preferences concerning sweetness and a pleasant dining atmosphere.
#
# User MmJ-gKRi3hRzBlVqEUEkOg → Improved Ranking: ['WdgQzBYDtTgcLahHvtiokA', 'U3i7AaegudvpmDL23_wEmQ', 'xD3L3JhNxsAfQikOHWHa4w', '58PYKm0WgNunAzuS4Qu1Zg', 'CfFGKTJ1RgdTYpY0fj1E5w']
# Overall Explanation: Based on the user's preference for a place to try for lunch with friends, the ranking has been adjusted to prioritize more casual and sociable venues that are excellent for midday meals.
# Details:
#   - WdgQzBYDtTgcLahHvtiokA: This restaurant offers a friendly atmosphere ideal for lunching with friends and a diverse menu.
#   - U3i7AaegudvpmDL23_wEmQ: Known for its great lunch specials, this spot is perfect for trying out new dishes with the group.
#   - xD3L3JhNxsAfQikOHWHa4w: A cozy place with a well-rounded menu that's perfect for a casual midday meal.
#   - 58PYKm0WgNunAzuS4Qu1Zg: While traditionally known for dinner, it does offer interesting lunch options making it worth considering.
#   - CfFGKTJ1RgdTYpY0fj1E5w: Although a strong contender, it is more suited for dinners and may not be as lively during lunchtime for groups of friends.
#
# User j8UlPZDO6K5iI8T7LKPqEA → Improved Ranking: ['J9rMt_V1NX49rU3YUjh_7Q', 'at7wfECnjgIJi5o7gL8fyQ', 'j_aIYB4uGOR45jAXivFNZQ', 'cEX4Cw8q2ftBrbpCvInf0w']
# Overall Explanation: The improved ranking considers user preferences for lunch options, group settings, and the type of dining experience desired.
# Details:
#   - J9rMt_V1NX49rU3YUjh_7Q: This restaurant is ideal for a large group looking for a varied lunch menu and a lively atmosphere.
#   - at7wfECnjgIJi5o7gL8fyQ: A great choice for lunch with convenient takeout options, perfect for those short on time.
#   - j_aIYB4uGOR45jAXivFNZQ: Offers a unique menu but is less suitable for larger groups or peak lunch times.
#   - cEX4Cw8q2ftBrbpCvInf0w: While a solid choice overall, it doesn't cater as well to group dining compared to the higher-ranked options.
#
# User 0gBy-cIXe0DQKhFjifu68Q → Improved Ranking: ['T7ekp7FiffoWDq53hbZDhg', 'O79uzVop5yqobf3bdjZzQg', '7LFdimtQU3yrgiKyE53klQ', 'LFknVw6uTIaL-MY_RqkN7g', '_HMiq7vSET4uhNScBdOJnw']
# Overall Explanation: The improved ranking is based on the user’s preference for a place suitable for groups with a good bar atmosphere and menu variety.
# Details:
#   - T7ekp7FiffoWDq53hbZDhg: This restaurant has a lively bar scene ideal for groups and offers a diverse menu.
#   - O79uzVop5yqobf3bdjZzQg: This place is known for its great atmosphere and variety of dishes, making it group-friendly.
#   - 7LFdimtQU3yrgiKyE53klQ: This option provides a fun bar environment, though slightly less focus on group dining compared to the top two.
#   - LFknVw6uTIaL-MY_RqkN7g: Although good for casual dining, it lacks a vibrant bar setting for larger gatherings.
#   - _HMiq7vSET4uhNScBdOJnw: This restaurant is less appealing for groups seeking a bar experience or extensive dish variety.
#
# User FAi3gMEwxhnh9tZRQiWwTg → Improved Ranking: ['I1wArJIYbFl2txUL6unC6A', 'KmKkhD-97CqPvokq5JIoBA', 'uQu5DtnXZZ8XVfBKldKnag', 'x44o1_Dw4QsQZRtBJgwZaA', '0hGE_UiUMAcF3PABcE-M4Q']
# Overall Explanation: The ranking has been adjusted based on the user's preferences for group settings, dish selection, and service quality with waitstaff.
# Details:
#   - I1wArJIYbFl2txUL6unC6A: Best suited for groups with a variety of dishes and excellent service from the waitstaff.
#   - KmKkhD-97CqPvokq5JIoBA: Offers a good atmosphere for friends and a solid dish selection, though service may vary.
#   - uQu5DtnXZZ8XVfBKldKnag: Great for groups with a lively environment and decent dish offerings, but slightly less consistent service.
#   - x44o1_Dw4QsQZRtBJgwZaA: While it has good dishes, it’s less ideal for larger groups and the service can be hit or miss.
#   - 0hGE_UiUMAcF3PABcE-M4Q: Typically a quieter setting with limited dish options, not as suitable for a group of friends.
#
# User fAY7S51J_9uMMZRVTO8f3w → Improved Ranking: ['Rwzp59f3Ia-v2V8Ku0zZWQ', '_HMiq7vSET4uhNScBdOJnw', 'J9rMt_V1NX49rU3YUjh_7Q', 'txwpCDw5Utu9WbM0VtYJqg']
# Overall Explanation: The ranking has been adjusted to better reflect the user's preferences for dinner options, group suitability, and selection of items and dishes.
# Details:
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: This restaurant offers a diverse menu that is well-suited for groups, making it ideal for a dinner setting.
#   - _HMiq7vSET4uhNScBdOJnw: Known for its unique and shareable dishes, this spot is perfect for a group gathering during dinner.
#   - J9rMt_V1NX49rU3YUjh_7Q: Offers excellent dinner options but has a more limited menu, making it slightly less favorable for diverse group preferences.
#   - txwpCDw5Utu9WbM0VtYJqg: While it has great items, it's not as group-friendly for dinner compared to the others.
#
# User a7y3gCq9Vwv89NRtUTtyJw → Improved Ranking: ['J9rMt_V1NX49rU3YUjh_7Q', '-WRbjOIgvQQ3jlJnvKUBNA', '6xx2FpMxjwabEHz_t2MiZg', '_HMiq7vSET4uhNScBdOJnw', 'ahlZC7XOKN-XJ7P4sPZrRg']
# Overall Explanation: The improved ranking prioritizes restaurants that enhance the social aspect preferred by the user and create a lively atmosphere suitable for hanging out with friends.
# Details:
#   - J9rMt_V1NX49rU3YUjh_7Q: This restaurant has a vibrant bar scene, making it ideal for socializing with friends.
#   - -WRbjOIgvQQ3jlJnvKUBNA: This place offers a trendy edge and a great atmosphere for group outings.
#   - 6xx2FpMxjwabEHz_t2MiZg: This restaurant has a chill vibe, perfect for casual meet-ups with friends.
#   - _HMiq7vSET4uhNScBdOJnw: Although good, it lacks the lively feel desired by the user, placing it lower.
#   - ahlZC7XOKN-XJ7P4sPZrRg: This location is better suited for a quieter experience, which does not align with the user’s preferences.
#
# User 1wWXchH7yRlFCxfC4dkQnA → Improved Ranking: ['-U4BnQL4VC3dkRDUZL0i8Q', '6LgTc7CZlXCd1Pxq3BiVcw', 'txwpCDw5Utu9WbM0VtYJqg', 'Rwzp59f3Ia-v2V8Ku0zZWQ.']
# Overall Explanation: The user prefers a restaurant that emphasizes a dining experience with a spacious setting and a variety of items on the menu.
# Details:
#   - -U4BnQL4VC3dkRDUZL0i8Q: This restaurant offers a spacious layout and a diverse menu, making it ideal for dinner.
#   - 6LgTc7CZlXCd1Pxq3BiVcw: This place has a good reputation for dinner options and a variety of dishes, though it is slightly smaller.
#   - txwpCDw5Utu9WbM0VtYJqg: While it has decent options, it doesn't provide the same level of space and variety as the top two.
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: This restaurant is less favorable in terms of items offered and overall space for a comfortable dining experience.
#
# User Nd-GGF74T3RKlty7PqM48A → Improved Ranking: ['I1wArJIYbFl2txUL6unC6A', 'n5vQCdHfl2Dm7r4l5FW8Cw', 'CTYFfHq1SWFyCeJ-KyIgOQ', 'IC15vAUX4EiMlWxxMehohw']
# Overall Explanation: The restaurants are ranked based on the user’s preference for trying different broths in a pleasant setting.
# Details:
#   - I1wArJIYbFl2txUL6unC6A: This restaurant is known for its diverse broth options and comfortable atmosphere, making it a top choice for trying new flavors.
#   - n5vQCdHfl2Dm7r4l5FW8Cw: Offers a solid variety of well-prepared broths and is appreciated for its spacious dining area.
#   - CTYFfHq1SWFyCeJ-KyIgOQ: While it serves great broth, the space may not be as inviting for those who value ambiance.
#   - IC15vAUX4EiMlWxxMehohw: This restaurant, although popular, has limited broth options compared to the others, which may not satisfy the user’s desire to try different kinds.
#
# User JxQmVUwbUBAZiji4kZtVSg → Improved Ranking: ['sxQdEEfKRviWRymOoH9UiA', 'JHi4LCxdbpXthg98sQiicQ', '_HMiq7vSET4uhNScBdOJnw', 'BYwoAKKtdSeylSN7QV8oNw', 'lE9qVePgvolkhw6C3Cdkeg']
# Overall Explanation: Based on the user's preference for a place that serves sandwiches for dinner and can accommodate a group, the ranking has been adjusted to prioritize restaurants that best fit these criteria.
# Details:
#   - sxQdEEfKRviWRymOoH9UiA: This restaurant is known for its exceptional sandwiches and has ample space for groups, making it the top choice.
#   - JHi4LCxdbpXthg98sQiicQ: A solid option that provides good sandwiches and a friendly atmosphere for dinner with friends.
#   - _HMiq7vSET4uhNScBdOJnw: Offers a limited sandwich menu but is set up to handle larger parties well.
#   - BYwoAKKtdSeylSN7QV8oNw: Known for quality food, but the selection of sandwiches is not as extensive as desired.
#   - lE9qVePgvolkhw6C3Cdkeg: While it has a great ambiance, it lacks group seating and sandwich options, placing it last.
#
# User qnIyZwh99Jhww8BhsfUg_w → Improved Ranking: ['new3Ny6i5ZJVn3m-i4A2Tg', 'Eo6RtLvIXcgSge6Z4Z6fFQ', 'Rwzp59f3Ia-v2V8Ku0zZWQ', 'EJNkmXMDWurCPjOZe_WXAg', 'xYGH13XolFh_yiQRo7bPJQ']
# Overall Explanation: Based on the user’s preferences for places that offer fries, bowls, and consider pricing in SGD, the ranking has been adjusted to better reflect these criteria.
# Details:
#   - new3Ny6i5ZJVn3m-i4A2Tg: This restaurant offers a variety of bowls and has highly-rated fries, making it very appealing for the user's preferences.
#   - Eo6RtLvIXcgSge6Z4Z6fFQ: Known for its great value and options for both bowls and fries, it ranks closely behind the top pick.
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: Offers decent meal options within budget and includes fries but is slightly lower in overall appeal.
#   - EJNkmXMDWurCPjOZe_WXAg: While it has some bowl options, the fries are less favored, affecting its ranking negatively.
#   - xYGH13XolFh_yiQRo7bPJQ: This place has limited offerings that align with the user’s preferences, making it the least favorable choice.
#
# User 8NyAypqBJG2JiSXBu7Vlug → Improved Ranking: ['MqdAYfl1p_c1144i48k6jw', '1nw-_Bm8sivTBZ7Z-uiVCA', 'o1_iIC0rU2yuF3SZvf6IjA', 'x0Pk5Uvy0y63FSzcfmxRpQ', '_HMiq7vSET4uhNScBdOJnw']
# Overall Explanation: The ranking has been adjusted to prioritize restaurants known for excellent food, service, and an ambiance suitable for dinner with friends.
# Details:
#   - MqdAYfl1p_c1144i48k6jw: Known for its outstanding food quality and inviting atmosphere, making it perfect for friends gathering.
#   - 1nw-_Bm8sivTBZ7Z-uiVCA: Offers great service and a lively environment, ideal for dinner with friends.
#   - o1_iIC0rU2yuF3SZvf6IjA: While it has good food, it lacks some of the ambiance desired for a social dinner.
#   - x0Pk5Uvy0y63FSzcfmxRpQ: Provides decent service but is less suited for a more intimate dinner setting.
#   - _HMiq7vSET4uhNScBdOJnw: Overall good, but it does not stand out compared to the others in terms of food and service for a dinner experience.
#
# User HO35wso-psqx0GF--QSwGA → Improved Ranking: ['Rwzp59f3Ia-v2V8Ku0zZWQ', 'ADtSvzL_abKwWPM1EL2yJw', 'BfGgttAzEPx9v7b8Sgkedw', 'J9rMt_V1NX49rU3YUjh_7Q']
# Overall Explanation: Based on the user's preferences for dinner, specific dishes, and potential ingredients, the ranking has been adjusted to better match the desired dining experience.
# Details:
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: This restaurant features a diverse menu, aligning well with the user's interest in specific dishes and ingredient variety.
#   - ADtSvzL_abKwWPM1EL2yJw: Known for its inviting atmosphere and suitable for dinner gatherings, making it a great choice for social dining.
#   - BfGgttAzEPx9v7b8Sgkedw: While it has popular dishes, it lacks variety in ingredients, placing it lower on the list.
#   - J9rMt_V1NX49rU3YUjh_7Q: This restaurant, though previously ranked higher, does not meet the user's preferences as strongly regarding specific ingredients and dinner focus.
#
# User jVoWhV1DT0peojYuH3HbLg → Improved Ranking: ['MqdAYfl1p_c1144i48k6jw', 'dFYfZsc-SUwRpDEgJiIoXA', '_HMiq7vSET4uhNScBdOJnw', 'P-X4kr5pDqXzhPEfa6RsTQ', 'uQu5DtnXZZ8XVfBKldKnag']
# Overall Explanation: Based on the user's preferences for place, sweetness, meat, food, and broth, the restaurants have been reordered to better fit their tastes.
# Details:
#   - MqdAYfl1p_c1144i48k6jw: This restaurant offers a strong variety of meaty dishes with a well-balanced broth, aligning well with the user's preferences.
#   - dFYfZsc-SUwRpDEgJiIoXA: Known for its sweet flavor profiles and hearty meat options, making it a perfect fit for the user's tastes.
#   - _HMiq7vSET4uhNScBdOJnw: This place has a focus on food quality and decent broth, slightly less sweet than the top two but still satisfying.
#   - P-X4kr5pDqXzhPEfa6RsTQ: While good, it does not emphasize sweetness as much, which is a key preference for the user.
#   - uQu5DtnXZZ8XVfBKldKnag: Ranked lowest due to a lack of emphasis on meat and broth, making it less appealing for the user's specific preferences.
#
# User UTzUG8exwDoHDW6V0BSE2w → Improved Ranking: ['XuxzGu2PEr59drHseZOVCg', '97DdiERj19Fuk5CRpHl0Hg', 'hinGqQYvot8HtRYxSdr6FA', 'WFtN3VJ4Tft0hQHl6NZaAA', 'fY1IkBnRft1KR0O2tqu7pg']
# Overall Explanation: The ranking has been adjusted based on the user’s preference for locations and dining spots that align with their request for a Singaporean context and vibrant ambiance ("faces" and "spot").
# Details:
#   - XuxzGu2PEr59drHseZOVCg: This restaurant offers a dynamic atmosphere and is known for its communal dining style, which fits the "faces" aspect well.
#   - 97DdiERj19Fuk5CRpHl0Hg: A vibrant spot with a lively ambiance that emphasizes social interaction, ideal for the user's preferences.
#   - hinGqQYvot8HtRYxSdr6FA: A well-reviewed restaurant with a solid reputation, though it doesn't fully capture the vibrant experience sought by the user.
#   - WFtN3VJ4Tft0hQHl6NZaAA: A popular choice, but it lacks the engaging environment the user seems to prefer.
#   - fY1IkBnRft1KR0O2tqu7pg: This place has great food but may fall short in offering the lively setting desired for social dining experiences.
#
# User 6G3tlx3-W5IH1lmaPXBSoQ → Improved Ranking: ['sxQdEEfKRviWRymOoH9UiA', 'J9rMt_V1NX49rU3YUjh_7Q', '7LFdimtQU3yrgiKyE53klQ', 'r0bjzYPVHwZo_DP66VLt4Q', 'VWLfePKMEj7g2P77RvRDuA']
# Overall Explanation: Based on the user preferences for place, flavour, service, food, and their location in Singapore, the ranking has been adjusted to highlight restaurants that offer a superior dining experience in these areas.
# Details:
#   - sxQdEEfKRviWRymOoH9UiA: This restaurant is known for its exceptional service and unique flavours that resonate well with the local palate.
#   - J9rMt_V1NX49rU3YUjh_7Q: Renowned for its vibrant atmosphere and diverse menu, it draws in diners looking for local Singaporean cuisine with a twist.
#   - 7LFdimtQU3yrgiKyE53klQ: While still offering good food, it lacks the standout service that other top choices provide.
#   - r0bjzYPVHwZo_DP66VLt4Q: Although it has solid flavours, it's set in a less desirable location compared to the top options.
#   - VWLfePKMEj7g2P77RvRDuA: Previously ranked higher, but it falls short on service and overall experience compared to the others on this list.
#
# User uSphcDFYUZW4cDBW7XPjdA → Improved Ranking: ['Rwzp59f3Ia-v2V8Ku0zZWQ', 'KmKkhD-97CqPvokq5JIoBA', 'J9rMt_V1NX49rU3YUjh_7Q', 'BYwoAKKtdSeylSN7QV8oNw', 'ahlZC7XOKN-XJ7P4sPZrRg']
# Overall Explanation: The ranking has been adjusted based on the user's preference for location, interaction with waitstaff, suitable ambiance for socializing, and pricing in Singapore.
# Details:
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: Best suited for social dining with attentive waitstaff and good pricing.
#   - KmKkhD-97CqPvokq5JIoBA: A close second, popular for its location and service quality.
#   - J9rMt_V1NX49rU3YUjh_7Q: Offers a pleasant atmosphere for groups, making it ideal for social interactions.
#   - BYwoAKKtdSeylSN7QV8oNw: Nice venue but slightly pricier, lowering its rank.
#   - ahlZC7XOKN-XJ7P4sPZrRg: While a decent option, it lacks the ambiance and service engagement found in the top choices.
#
# User 8uhSaRacb0fkPxe4re4StA → Improved Ranking: ['tz8VEeIOoM5Cu1NSnC2JIQ', 'JHi4LCxdbpXthg98sQiicQ', 'x0Pk5Uvy0y63FSzcfmxRpQ', 'Lv5GFFciSK532QIX2ZLqjg', '_HMiq7vSET4uhNScBdOJnw']
# Overall Explanation: Based on the user's preference for a place that accommodates groups and offers meat options, the ranking has been adjusted to highlight restaurants that excel in these areas.
# Details:
#   - tz8VEeIOoM5Cu1NSnC2JIQ: This restaurant has ample space for groups and features a robust meat selection, making it ideal for gatherings.
#   - JHi4LCxdbpXthg98sQiicQ: Known for its spacious layout and variety of meat dishes, this place is also well-suited for larger crowds.
#   - x0Pk5Uvy0y63FSzcfmxRpQ: Although it offers a decent selection, it doesn't quite match the group-friendliness of the top two options.
#   - Lv5GFFciSK532QIX2ZLqjg: This restaurant is more limited in space and meat choices, putting it lower in priority for group gatherings.
#   - _HMiq7vSET4uhNScBdOJnw: Ranked last, it lacks both room for larger groups and a variety of meat options, making it less appealing for the user's preferences.
#
# User Z9z67ChosXkTjjNAtFmN7w → Improved Ranking: ['_7nMWBmfFvk9S3tKG3Ip_g', 'EJNkmXMDWurCPjOZe_WXAg', 'qs6gA9Y5sRzpXnm_4QaP0Q', 'vVqxGrqt5ALxQjJGnntpKQ']
# Overall Explanation: Based on the user's preferences for a place that focuses on dishes like pulled pork, I have re-ranked the restaurants accordingly.
# Details:
#   - _7nMWBmfFvk9S3tKG3Ip_g: Known for its pulled pork offerings, making it the top choice for the user's specified dish.
#   - EJNkmXMDWurCPjOZe_WXAg: Offers a great variety of smoked meats including pulled pork, enhancing its ranking.
#   - qs6gA9Y5sRzpXnm_4QaP0Q: While not as focused on pulled pork, it still serves quality dishes in a good setting.
#   - vVqxGrqt5ALxQjJGnntpKQ: Doesn't specialize in pulled pork or related dishes, placing it last in this context.
#
# User 6sRkV6dUa2TigWeVi4P9FQ → Improved Ranking: ['KPrdWch1680ihzVe3C-s3w', 'LFknVw6uTIaL-MY_RqkN7g', 'vVqxGrqt5ALxQjJGnntpKQ', 'Xtr2M_mh9_jOkmpNd_CSCA', '6LgTc7CZlXCd1Pxq3BiVcw']
# Overall Explanation: Based on the user’s preference for food quality, particularly pulled pork and steak, the ranking has been adjusted to prioritize restaurants known for their meat offerings and the overall dining experience.
# Details:
#   - KPrdWch1680ihzVe3C-s3w: Known for its exceptional steak and barbecue options, making it a top choice for meat lovers.
#   - LFknVw6uTIaL-MY_RqkN7g: Offers great pulled pork dishes that align perfectly with user preferences for high-quality food.
#   - vVqxGrqt5ALxQjJGnntpKQ: A solid option with good food, but slightly less focused on the pulled pork and steak.
#   - Xtr2M_mh9_jOkmpNd_CSCA: A decent restaurant with variety, but doesn't specialize in the user's preferred meat dishes as highly as others.
#   - 6LgTc7CZlXCd1Pxq3BiVcw: Lower in rank due to less emphasis on high-quality pulled pork and steak compared to others.
#
# User sF0HEhcWb13p_txmssFotw → Improved Ranking: ['U3i7AaegudvpmDL23_wEmQ', 'vZiWYH4XIiy3fqPNy615Kg', 'EECw-s6Jy-fyJHhkUGQhHg', 'NCwX8t4pHpcAMzSCaC2Hww', '3vr42-TF3V31LrN5sAFbDQ']
# Overall Explanation: The ranking has been adjusted to prioritize restaurants that specialize in fish and chips, while also considering the overall ambiance for a pleasant meal experience and coffee availability.
# Details:
#   - U3i7AaegudvpmDL23_wEmQ: This restaurant excels in serving fish and chips, has a great location for a casual meal by the water, and offers decent coffee options, making it the top choice.
#   - vZiWYH4XIiy3fqPNy615Kg: Known for its bustling atmosphere and solid fish and chips, this place also serves good coffee, which aligns well with user preferences.
#   - EECw-s6Jy-fyJHhkUGQhHg: Offers a robust menu featuring fish and chips, but the ambiance is slightly less favorable compared to the top two options.
#   - NCwX8t4pHpcAMzSCaC2Hww: While they serve tasty fish and chips, the coffee selection may not be as appealing as other spots in the list.
#   - 3vr42-TF3V31LrN5sAFbDQ: This restaurant is more renowned for other dishes rather than fish and chips, placing it last in the ranking despite having a good coffee menu.
#
# User owI_FQdAKZQFY8UnkQoD8g → Improved Ranking: ['Eo87r_6a9Z3L_a8f9zVoow', 'eKctA6ndawB61VrmSF-dXw', 'NKkh6R7i2DQbUtyd5IdG_A', 'VZcs1K7A31sNQurNXs9gaQ']
# Overall Explanation: The new ranking prioritizes restaurants that excel in place, staff, and coffee quality, aligning better with user preferences.
# Details:
#   - Eo87r_6a9Z3L_a8f9zVoow: This restaurant has a vibrant atmosphere, friendly staff, and highly-rated coffee, making it a top choice.
# ...
#   - _kuDz_Uf6JbARZEfNpkl8Q: While it has a somewhat limited menu, it includes fresh fruit options and generally maintains a cautious approach to its dishes.
#   - lE9qVePgvolkhw6C3Cdkeg: This restaurant is a favorite for its consistency but lacks the variety of fruity menu items that the user prefers.
#   - _e7yPjlgOAF7z8PssDamug: Although it offers some safe options, it does not highlight fruits prominently enough to meet the user's specific preference.
#
# User xFDRt8cv--y1tvEhqX_DHw → Improved Ranking: ['I1wArJIYbFl2txUL6unC6A', 'EqdAzi9c5xuhxN9brmEaZw', 'hSEGyy0-i1_ZXGIRySbgcg', 'LFknVw6uTIaL-MY_RqkN7g', 'vVqxGrqt5ALxQjJGnntpKQ']
# Overall Explanation: The ranking has been improved to prioritize restaurants that cater better to a total dining experience, focusing on food quality and atmosphere suitable for a couple dining together.
# Details:
#   - I1wArJIYbFl2txUL6unC6A: This restaurant offers a highly rated culinary experience and a romantic atmosphere, perfect for dining with your wife.
#   - EqdAzi9c5xuhxN9brmEaZw: Known for its diverse and delicious menu options, this place is another great spot for couples looking to enjoy quality food together.
#   - hSEGyy0-i1_ZXGIRySbgcg: Although slightly less focused on the dining atmosphere, it still provides good food and can accommodate couples well.
#   - LFknVw6uTIaL-MY_RqkN7g: This restaurant is solid but doesn't quite match the overall dining experience and ambiance that is preferable for a couple.
#   - vVqxGrqt5ALxQjJGnntpKQ: While it has its merits, it ranks lowest due to less emphasis on the romantic dining experience and overall atmosphere.
#
# User BDLd6HfU_C6-6URrLRLrnw → Improved Ranking: ['at7wfECnjgIJi5o7gL8fyQ', 'bjL1PC2e9dvjBVewmoXYwQ', 'Rl318hUrGlkPJhMmNNZizQ', 'U3i7AaegudvpmDL23_wEmQ', 'Dn83poKTVhWL3ItLdalmYw']
# Overall Explanation: The improved ranking prioritizes restaurants based on the quality of service, social atmosphere, and food experience that cater to the user’s preferences for a great place to dine with people.
# Details:
#   - at7wfECnjgIJi5o7gL8fyQ: Offers excellent service and a vibrant atmosphere ideal for socializing.
#   - bjL1PC2e9dvjBVewmoXYwQ: Known for its fantastic food and attentive staff, making it a great place to enjoy with others.
#   - Rl318hUrGlkPJhMmNNZizQ: Although good, it doesn't quite match the social vibe of the top two.
#   - U3i7AaegudvpmDL23_wEmQ: A good place but sometimes lacks the service quality prioritized by the user.
#   - Dn83poKTVhWL3ItLdalmYw: This restaurant offers decent food but doesn't provide the lively atmosphere the user desires.
#
# User 6OaTrornYAPhU-M7A8wubg → Improved Ranking: ['1nw-_Bm8sivTBZ7Z-uiVCA', 'sxQdEEfKRviWRymOoH9UiA', 'CdAmgWWCabZQoYNNWOKcEw', 'UPRFpMsB4I64GRjUqjRmiw']
# Overall Explanation: Based on the user's preferences for people, service, and food in Singapore, the ranking has been adjusted to prioritize these factors while considering the previous order.
# Details:
#   - 1nw-_Bm8sivTBZ7Z-uiVCA: Known for excellent service and a vibrant atmosphere, making it ideal for social dining experiences.
#   - sxQdEEfKRviWRymOoH9UiA: High-quality food and service, popular among locals which enhances the social aspect.
#   - CdAmgWWCabZQoYNNWOKcEw: Offers good food but slightly less emphasis on service and atmosphere compared to the top two.
#   - UPRFpMsB4I64GRjUqjRmiw: While it has decent food, it falls short in service and the welcoming atmosphere preferred by the user.
#
# User MsNATWFEcNUtF48INY7Kig → Improved Ranking: ['J9rMt_V1NX49rU3YUjh_7Q', 'AQEEH7JP1DFrvFuMi6TP2Q', 'Z9oNUI_dlEKjhEWuG-hxPA', 'n2CnBRKK82cWZ9a2OjS2xQ', 'Po0Qb6X_g8b00OggqtATRA']
# Overall Explanation: The improved ranking prioritizes the quality of service, food, and overall dining experience, particularly in a Singapore context, which aligns with the user's preferences.
# Details:
#   - J9rMt_V1NX49rU3YUjh_7Q: Best reputation for service quality and consistent food excellence in Singapore.
#   - AQEEH7JP1DFrvFuMi6TP2Q: Known for attentive staff and a pleasant dining atmosphere.
#   - Z9oNUI_dlEKjhEWuG-hxPA: Offers a unique menu with good service, making it a popular choice.
#   - n2CnBRKK82cWZ9a2OjS2xQ: Good food but slightly lacking in service compared to those ranked above.
#   - Po0Qb6X_g8b00OggqtATRA: While it has decent food, service experiences have been inconsistent recently.
#
# User bF6PqsugCWjBZ-RVIJzrmQ → Improved Ranking: ['NMz0wMYMTnsyC_sulMLwlA', 'TzKx4KbFOzLX0v7F31cSpw', 'MqdAYfl1p_c1144i48k6jw', 'NCwX8t4pHpcAMzSCaC2Hww']
# Overall Explanation: The ranking has been adjusted to prioritize restaurants that excel in service and offer pizza options in Singapore, aligning with the user's preferences for dining experiences.
# Details:
#   - NMz0wMYMTnsyC_sulMLwlA: This restaurant is known for outstanding service and has a diverse pizza menu, making it the top choice for the user.
#   - TzKx4KbFOzLX0v7F31cSpw: A solid choice for pizza lovers, it also offers a comfortable dining atmosphere and good service, placing it second.
#   - MqdAYfl1p_c1144i48k6jw: While it serves pizza, the service is fairly average compared to the top two, which impacts its ranking.
#   - NCwX8t4pHpcAMzSCaC2Hww: This option is further down the list primarily due to less favorable service reviews despite having a reasonable food selection.
#
# User BbAr5pdyz1kPApiilQA2jQ → Improved Ranking: ['_HMiq7vSET4uhNScBdOJnw', 'YnnYwfMEeSru_cJ_qKeofw', 'ahlZC7XOKN-XJ7P4sPZrRg', 'J9rMt_V1NX49rU3YUjh_7Q']
# Overall Explanation: The revised ranking reflects restaurants that excel in service and food quality, with a focus on their location in Singapore.
# Details:
#   - _HMiq7vSET4uhNScBdOJnw: Renowned for its exceptional service and high-quality cuisine, making it a standout option.
#   - YnnYwfMEeSru_cJ_qKeofw: Offers excellent food in a great location, complemented by friendly service.
#   - ahlZC7XOKN-XJ7P4sPZrRg: Good food and service, but slightly less appealing location compared to the top choices.
#   - J9rMt_V1NX49rU3YUjh_7Q: While it has decent offerings, it does not match the overall experience provided by the others.
#
# User muNBd72RI-WhHLlwIYaWRA → Improved Ranking: ['6LgTc7CZlXCd1Pxq3BiVcw', 'vVqxGrqt5ALxQjJGnntpKQ', 'i5dxKKLe2kJ8WbPUXilPGg', 'x44o1_Dw4QsQZRtBJgwZaA', 'r1W_Co451x1A1GCMkukMNw']
# Overall Explanation: Based on the user's preferences for service, food quality, restaurant atmosphere, price, and seasoning, the ranking emphasizes establishments known for their excellent service and flavorful dishes while still being affordable.
# Details:
#   - 6LgTc7CZlXCd1Pxq3BiVcw: This restaurant is known for its outstanding service and a menu that beautifully highlights seasoning, making it a top choice for the user.
#   - vVqxGrqt5ALxQjJGnntpKQ: This spot offers a great balance of delicious food and good service at reasonable prices, which appeals to the user's preferences.
#   - i5dxKKLe2kJ8WbPUXilPGg: Placed here for its decent food quality and service, but may not shine as brightly in terms of seasoning compared to others above it.
#   - x44o1_Dw4QsQZRtBJgwZaA: While it has good food, the service and overall experience do not match the top-ranked restaurants, reducing its appeal.
#   - r1W_Co451x1A1GCMkukMNw: This restaurant falls last due to inconsistent service and flavor profiles that do not align well with the user's seasoning preference.
#
# User 8VAqRRuJy2oaZAVL9QZ49Q → Improved Ranking: ['e7Yr0xwLi73tP2aQ2PjA_w', 'gMZsbtlUdmhGOFf_yyDE2Q', 'vVUPpLa7C0PCqhWHPDaLfQ', 'nCwEzk4Z1lX5PvLEYpbBHw', 'DDd3TW3lDvQduqmw-UkrUg']
# Overall Explanation: Based on the user’s preferences for service, food quality, lunch options, order convenience, and credit card acceptance, the restaurants have been rearranged to better meet these criteria.
# Details:
#   - e7Yr0xwLi73tP2aQ2PjA_w: Known for excellent service and a variety of lunch options, making it a top choice for quick orders.
#   - gMZsbtlUdmhGOFf_yyDE2Q: Offers great food quality with prompt service and accepts credit cards, suitable for lunch takeout.
#   - vVUPpLa7C0PCqhWHPDaLfQ: Provides decent service and food but may have less convenient order options compared to the top two.
#   - nCwEzk4Z1lX5PvLEYpbBHw: Good food but slower service and may not cater to lunch orders as efficiently.
#   - DDd3TW3lDvQduqmw-UkrUg: Although it has good food, it is ranked lower due to less favorable service and order processes for lunch.
#
# User tcl9C7lTC6BKq9AlnJFplQ → Improved Ranking: ['LFknVw6uTIaL-MY_RqkN7g', 'J9rMt_V1NX49rU3YUjh_7Q', '0W5UWAcjwGuCJOv8rXGMqw', '6xx2FpMxjwabEHz_t2MiZg', 'at7wfECnjgIJi5o7gL8fyQ.']
# Overall Explanation: Based on the user's focus on service, food quality, drinks selection, good service, and a pleasant view, I've adjusted the rankings to prioritize these aspects.
# Details:
#   - LFknVw6uTIaL-MY_RqkN7g: This restaurant excels in both service and food quality, with an impressive drinks menu and beautiful views that enhance the dining experience.
#   - J9rMt_V1NX49rU3YUjh_7Q: Noted for its exceptional service and delightful food offerings, this spot also provides a nice ambiance, making it a solid choice for the user’s preferences.
#   - 0W5UWAcjwGuCJOv8rXGMqw: While praised for its food, the service has been inconsistent, although it still offers decent drink selections and a pleasant atmosphere.
#   - 6xx2FpMxjwabEHz_t2MiZg: Offers good food and drinks but lacks the standout service and scenic views that the user prefers.
#   - at7wfECnjgIJi5o7gL8fyQ: Initially ranked higher, but it has been noted for underwhelming service and food quality, thus lowering its position in this recommendation.
#
# User sa2jTUdR3kasSZea_W9RZA → Improved Ranking: ['K0jxSR_b1Bm4vmjCeSx9qA', 'gzBoOo4E1ornEHYod52uew', 'U3i7AaegudvpmDL23_wEmQ', 'ymAw53bQVppVV7T40fNgRw', 'iNVn7TsdKzgrYfRWmWTQOg']
# Overall Explanation: Based on the user's preference for food quality, Singaporean cuisine, ambience, rice, and curry, the ranking has been adjusted to highlight the restaurants that best meet these criteria.
# Details:
#   - K0jxSR_b1Bm4vmjCeSx9qA: Known for its authentic Singaporean curry dishes and a vibrant atmosphere that enhances the dining experience.
#   - gzBoOo4E1ornEHYod52uew: Offers a fantastic variety of rice-based meals and curries, with a warm ambience perfect for enjoying meals.
#   - U3i7AaegudvpmDL23_wEmQ: A versatile menu featuring local flavors and a cozy setting, though slightly less focused on curry.
#   - ymAw53bQVppVV7T40fNgRw: While it has good food and ambience, it may not offer a strong emphasis on curry or rice dishes.
#   - iNVn7TsdKzgrYfRWmWTQOg: Although enjoyable, it ranks lower as it does not specialize in the user's preferred cuisine types.
#
# User CpGjjYQ8LRBmAn6ARE9qWA → Improved Ranking: ['KX5KY8fLlMoJMS1NAj0Pvw', 'mcFT96dzIsrtGdd9JNmIzw', 'Xtr2M_mh9_jOkmpNd_CSCA', '0e30ReHOmL2GzY_3hEy_Ig']
# Overall Explanation: The ranking is adjusted to prioritize restaurants that offer a diverse selection of food and cater to morning dining preferences.
# Details:
#   - KX5KY8fLlMoJMS1NAj0Pvw: This restaurant is known for its extensive breakfast menu and variety of options, making it ideal for morning dining.
#   - mcFT96dzIsrtGdd9JNmIzw: Offers a good selection of food that is suitable for various tastes, but is slightly less specialized for morning meals.
#   - Xtr2M_mh9_jOkmpNd_CSCA: While it has quality offerings, it lacks the same level of selection for breakfast items as the top two.
#   - 0e30ReHOmL2GzY_3hEy_Ig: This restaurant has the least focus on morning dining and is therefore placed last due to user preferences.
#
# User -_iULENf28RbqL2k0ja5Xw → Improved Ranking: ['Rwzp59f3Ia-v2V8Ku0zZWQ', 'NbQH02mMYJ4r1RqvG2FDBA', 'ADtSvzL_abKwWPM1EL2yJw']
# Overall Explanation: Based on the user's preference for rice dishes typically found in Singaporean cuisine, I have adjusted the ranking to prioritize restaurants that are known for their Singaporean rice dishes and a friendly atmosphere.
# Details:
#   - Rwzp59f3Ia-v2V8Ku0zZWQ: Known for its authentic Singaporean rice dishes and a welcoming vibe, making it ideal for dining with a friend.
#   - NbQH02mMYJ4r1RqvG2FDBA: Offers a variety of rice options with a focus on local flavors, while still providing a friendly environment.
#   - ADtSvzL_abKwWPM1EL2yJw: Although it serves rice dishes, it may not offer as strong a Singaporean flavor or the same level of friendliness as the others.
#
# User jV3vIpih0GPmIXOtXqs0VA → Improved Ranking: ['DDd3TW3lDvQduqmw-UkrUg', '7LFdimtQU3yrgiKyE53klQ', 'NbQH02mMYJ4r1RqvG2FDBA', 'pKNDz1tzC5llbengNUz_7w']
# Overall Explanation: Given the user's preference for Singaporean cuisine with a focus on rice dishes, price, drinks, and flavor, adjustments were made to prioritize places known for these attributes.
# Details:
#   - DDd3TW3lDvQduqmw-UkrUg: This restaurant excels in authentic Singaporean rice dishes and offers a variety of drinks, aligning well with the user’s preferences.
#   - 7LFdimtQU3yrgiKyE53klQ: Known for its flavorful rice options, it provides good value and a selection of beverages that appeal to the user's taste.
#   - NbQH02mMYJ4r1RqvG2FDBA: Offers decent rice dishes at reasonable prices, but lacks the drink variety of the top two.
#   - pKNDz1tzC5llbengNUz_7w: While it has some flavor, its offerings are less focused on rice and drinks compared to the others, making it the least preferred option.
#
# User WwTYfD8TysD1isAEhSEOoA → Improved Ranking: ['lJ5YkS5fxC8dcSK4FPtyYQ', 'J9rMt_V1NX49rU3YUjh_7Q', 'bjL1PC2e9dvjBVewmoXYwQ', 'MfspClBaUOwUwj7BBf3xSw']
# Overall Explanation: Based on the user's preferences for Singaporean cuisine, a stellar ambiance, small size, and fast service, the restaurants have been reordered to better match these criteria.
# Details:
#   - lJ5YkS5fxC8dcSK4FPtyYQ: Known for its exceptional Singaporean offerings and intimate setting, providing a great ambiance.
#   - J9rMt_V1NX49rU3YUjh_7Q: Offers a cozy environment with quick service, appealing to the user's preference for fast dining.
#   - bjL1PC2e9dvjBVewmoXYwQ: Provides a decent menu but lacks the ambiance and quick service the user desires.
#   - MfspClBaUOwUwj7BBf3xSw: While it may have good food, it doesn't quite match the request for ambiance and speed.
#
# User NvVj9v3RvQRZuYwnkRjU2w → Improved Ranking: ['i5dxKKLe2kJ8WbPUXilPGg', 'avrJOt2Kzk7fUpe4D4_DAQ', 'x0Pk5Uvy0y63FSzcfmxRpQ', 'J9rMt_V1NX49rU3YUjh_7Q', 'fY1IkBnRft1KR0O2tqu7pg']
# Overall Explanation: Based on the user preferences for a meal that ends well in a bowl format with substantial portions and a diverse menu, the restaurants have been reordered to highlight those attributes.
# Details:
#   - i5dxKKLe2kJ8WbPUXilPGg: Offers hearty bowl meals with a wide variety of choices that cater well to portion preferences.
#   - avrJOt2Kzk7fUpe4D4_DAQ: Known for its flavorful bowls and generous servings that align with user’s desire for a satisfying meal.
#   - x0Pk5Uvy0y63FSzcfmxRpQ: Provides decent bowl options but with a less diverse menu than the top two recommendations.
#   - J9rMt_V1NX49rU3YUjh_7Q: While offering good meals, it falls short in portion size compared to higher-ranked restaurants.
#   - fY1IkBnRft1KR0O2tqu7pg: Ranked last due to limited bowl offerings and smaller portions that may not satisfy the user's preferences.
#
# User MBM7W-xDSEJkYpYPUT6-vA → Improved Ranking: ['Yf4RhB-uTRcZc3l-1icBmw', 'TzKx4KbFOzLX0v7F31cSpw', 'JG3Yw6z48y6Eyi0DnN19tQ', '4ZOXsBhHx2EzrTwACILK2A']
# Overall Explanation: The ranking has been adjusted to prioritize restaurants that are known for their breakfast and lunch offerings, aligning better with the user's preferences.
# Details:
#   - Yf4RhB-uTRcZc3l-1icBmw: This restaurant specializes in a variety of breakfast and brunch options, making it ideal for the user's preference for breakfast and lunch meals.
#   - TzKx4KbFOzLX0v7F31cSpw: A popular spot known for its all-day breakfast, ensuring satisfying meal choices any time of the day.
#   - JG3Yw6z48y6Eyi0DnN19tQ: Offers decent lunch options, but is less focused on breakfast compared to the top two.
#   - 4ZOXsBhHx2EzrTwACILK2A: While it has good lunch offerings, it lacks a strong breakfast menu, making it the least suitable option for the user.

# %%
# Hàm trả về kết quả dạng dictionary để sử dụng cho hệ thống
def generate_results(test_users, results, test_users2kw, restaurant_set, re_ranked):
    output_data = {}
    for idx, (user, restaurant_indices) in enumerate(zip(test_users, results)):
        user_data = {}
        user_keywords = test_users2kw[idx]
        candidate_restaurants = [restaurant_set[i] for i in restaurant_indices]
        re_ranked_restaurants = re_ranked[idx]
        positions = [str(i) for i in restaurant_indices]
        user_data["kw"] = user_keywords[:5]
        user_data["candidate"] = re_ranked_restaurants[:5]
        user_data["positions"] = positions[:5]
        output_data[user] = user_data
    return output_data 

result_dict = generate_results(test_users, results, test_users2kw, restaurant_set, final_results)
print(result_dict)
# Out:
# {'H8mXfh5XgGCqmMLwVH7k5A': {'kw': ['place', 'instagram', 'voucher', 'other friends', 'shop front'], 'candidate': ['MPzZuWpKpeLBa833zzL9IQ', 'SxT7tgTNxkVuk67XEl7p8g', '2tGFUtUrE0DhwlX59pbArA', 'x0Pk5Uvy0y63FSzcfmxRpQ', 'fY1IkBnRft1KR0O2tqu7pg'], 'positions': ['274', '44', '533', '873', '816']}, 'QZqj0zcaOXV63mVVVLAhhQ': {'kw': ['place', 'bar', 'items', 'steak', 'desserts'], 'candidate': ['vVqxGrqt5ALxQjJGnntpKQ', 'Rwzp59f3Ia-v2V8Ku0zZWQ', 'VEy3-SnvsKgWfGM_b2irbA', 'n2CnBRKK82cWZ9a2OjS2xQ', 'f6SN9YUSpb9AjS4hnFgyxg'], 'positions': ['331', '207', '730', '680', '890']}, 'J-NdrqdYuaBZnD8zo9pgjg': {'kw': ['place', 'sandwiches', 'dinner', 'lot', 'batter'], 'candidate': ['Rwzp59f3Ia-v2V8Ku0zZWQ', 'J9rMt_V1NX49rU3YUjh_7Q', 'I1wArJIYbFl2txUL6unC6A', '_HMiq7vSET4uhNScBdOJnw'], 'positions': ['680', '415', '570', '22', '410']}, 'XsIVj_AszmnnsykBrKgdHw': {'kw': ['place', 'ingredients', 'meat', 'desserts', 'people'], 'candidate': ['NbQH02mMYJ4r1RqvG2FDBA', 'YnnYwfMEeSru_cJ_qKeofw', 'x44o1_Dw4QsQZRtBJgwZaA', 'wxf-tyEbFaatpJL-43JJpQ', 'hSEGyy0-i1_ZXGIRySbgcg'], 'positions': ['982', '278', '485', '944', '29']}, 'ok0fpB6QHkSUpTQpO3UAfA': {'kw': ['place', 'edge', 'dinner', 'dish', 'friends'], 'candidate': ['Rwzp59f3Ia-v2V8Ku0zZWQ', 'fqhahiKsc6gPs5Sx4mf9Vg', 'Pv0P0vYFIOlMPPfn18Wc7Q', 'vVqxGrqt5ALxQjJGnntpKQ'], 'positions': ['122', '680', '207', '459', '469']}, 'gekp2Z5I4vPGf2NeFnZX2A': {'kw': ['place', 'dinner', 'lot', 'dish', 'meat'], 'candidate': ['3n_2L-oqqw6noFKsb3qmeg', '7LFdimtQU3yrgiKyE53klQ', 'YnnYwfMEeSru_cJ_qKeofw', 'txwpCDw5Utu9WbM0VtYJqg', 'ZhJ59SFPifQiTW0gAddfGw'], 'positions': ['982', '645', '788', '797', '469']}, 'JXrx-kwCSuf1xCkwuv0Nfw': {'kw': ['place', 'truffle oil', 'fries', 'side', 'meat'], 'candidate': ['f6SN9YUSpb9AjS4hnFgyxg', 'l5lEOq47ne-jWKl67VKwZA', 'kA5pZz-koXIlPaDJALDroQ', 'ib_206uhcdzV7lNcCpniXA', 'ko4q1Oj4iWvYSxoamlcEgw'], 'positions': ['20', '105', '890', '520', '284']}, 'FQZZsU3J88IGF8n5e3XYZg': {'kw': ['place', 'dinner', 'lot', 'bunch', 'dish'], 'candidate': ['Rl318hUrGlkPJhMmNNZizQ', 'P-X4kr5pDqXzhPEfa6RsTQ', 'ko4q1Oj4iWvYSxoamlcEgw', '_HMiq7vSET4uhNScBdOJnw', 'I1wArJIYbFl2txUL6unC6A'], 'positions': ['415', '22', '495', '284', '960']}, 'UwWtpjalT2xlJyglRRITug': {'kw': ['place', 'dinner', 'lot', 'dish', 'hours'], 'candidate': ['BYwoAKKtdSeylSN7QV8oNw', '7LFdimtQU3yrgiKyE53klQ', 'Ku333V1F3_9MVKUJ72_ZBw', '_HMiq7vSET4uhNScBdOJnw', 'x44o1_Dw4QsQZRtBJgwZaA'], 'positions': ['469', '415', '366', '738', '278']}, 'uOTNLX7v8MyEikB1yVux3Q': {'kw': ['place', 'dinner', 'group', 'friends', 'side'], 'candidate': ['9R5laAm5Kv4aBLVtH1gVnA', 'txwpCDw5Utu9WbM0VtYJqg', 'I1wArJIYbFl2txUL6unC6A', 'MPzZuWpKpeLBa833zzL9IQ', 'ZSpfF89JnQN6fiS8OhBlZQ'], 'positions': ['797', '533', '344', '736', '22']}, 'sZ3mumX9WjJqp6qrjPPUBQ': {'kw': ['place', 'bar', 'sandwiches', 'dinner', 'lot'], 'candidate': ['lE9qVePgvolkhw6C3Cdkeg', 'T7ekp7FiffoWDq53hbZDhg', '_HMiq7vSET4uhNScBdOJnw', 'YkVRDcEa7vZK65u-tlL9tQ'], 'positions': ['415', '680', '475', '849', '568']}, 'g8VcsAZyMrak3vdrLr3b7w': {'kw': ['place', 'dinner', 'group', 'friends', 'meat'], 'candidate': ['JHi4LCxdbpXthg98sQiicQ', 'rXhvV-YyZaJLjgOnz7_jkA', 'tz8VEeIOoM5Cu1NSnC2JIQ', '_HMiq7vSET4uhNScBdOJnw'], 'positions': ['885', '415', '157', '850', '816']}, '1tQfj737uhgdKcQ-5akTdA': {'kw': ['place', 'dinner', 'lot', 'dish', 'spices'], 'candidate': ['M-PobdAR2gJhPyLR_WzMCQ', 'OExxlOVjUIDh3TFjPzbSDA', '58PYKm0WgNunAzuS4Qu1Zg', '7LFdimtQU3yrgiKyE53klQ', 'qs6gA9Y5sRzpXnm_4QaP0Q'], 'positions': ['335', '669', '317', '469', '509']}, '1UZs_9wFHP4NR_62LwGD6g': {'kw': ['place', 'shop', 'sandwiches', 'dinner', 'lot'], 'candidate': ['MPzZuWpKpeLBa833zzL9IQ', 'x0Pk5Uvy0y63FSzcfmxRpQ', 'vVqxGrqt5ALxQjJGnntpKQ', '_HMiq7vSET4uhNScBdOJnw', '_7nMWBmfFvk9S3tKG3Ip_g'], 'positions': ['533', '816', '207', '534', '415']}, 'TUAiW8Lcdla5Ii53kV6RFw': {'kw': ['place', 'sandwiches', 'dinner', 'lot', 'group'], 'candidate': ['VEy3-SnvsKgWfGM_b2irbA', 'NbQH02mMYJ4r1RqvG2FDBA', '5LMkTnMXOxlce_LwUNhpCQ', 'J3ijSN86u_Pg42BZjkDM_g', 'Eq ...

# %%
# # Hàm lưu kết quả vào file JSON để kiểm tra nhanh
# def save_rerank_results_to_json(test_users, results, test_users2kw, restaurant_set, re_ranked, file_path='./data/.json'):
#     output_data = {}
#     for idx, (user, restaurant_indices) in enumerate(zip(test_users, results)):
#         user_data = {}  
#         user_keywords = test_users2kw[idx]
#         candidate_restaurants = [restaurant_set[i] for i in restaurant_indices]
#         re_ranked_restaurants = re_ranked[idx]
#         positions = [str(i) for i in restaurant_indices]
#         user_data["kw"] = user_keywords[:10]
#         user_data["candidate"] = re_ranked_restaurants[:10]
#         user_data["positions"] = positions[:10]
#         output_data[user] = user_data
#     with open(file_path, mode="w", encoding="utf-8") as json_file:
#         json.dump(output_data, json_file, ensure_ascii=False, indent=4)
#     print(f"Results saved to: {file_path}")

# save_rerank_results_to_json(test_users, results, test_users2kw, restaurant_set, final_results)

# %%
def generate_full_results(test_users, results, test_users2kw, restaurant_set, re_ranked, explanations):
    output_data = {}
    for idx, user in enumerate(test_users):
        kws = test_users2kw[idx][:5]
        cand = re_ranked[idx][:5]
        # orig = [restaurant_set[i] for i in results[idx]][:5]
        exp = explanations[idx]
        output_data[user] = {
            "kw": kws,
            "candidate": cand,
            "explanation": exp
        }
    return output_data

generate_full_results(test_users, results, test_users2kw, restaurant_set, final_results, final_detailed_explanations)
# Out:
# {'H8mXfh5XgGCqmMLwVH7k5A': {'kw': ['place',
#    'instagram',
#    'voucher',
#    'other friends',
#    'shop front'],
#   'candidate': ['MPzZuWpKpeLBa833zzL9IQ',
#    'SxT7tgTNxkVuk67XEl7p8g',
#    '2tGFUtUrE0DhwlX59pbArA',
#    'x0Pk5Uvy0y63FSzcfmxRpQ',
#    'fY1IkBnRft1KR0O2tqu7pg'],
#   'explanation': {'MPzZuWpKpeLBa833zzL9IQ': 'Known for aesthetically pleasing presentation, ideal for Instagram posts.',
#    'SxT7tgTNxkVuk67XEl7p8g': 'Has a trendy shop front that is very inviting and popular among friends.',
#    '2tGFUtUrE0DhwlX59pbArA': 'Good overall experience with some unique features that are nice for groups.',
#    'x0Pk5Uvy0y63FSzcfmxRpQ': 'Offers occasional vouchers, which could be useful but lacks strong Instagram appeal.',
#    'fY1IkBnRft1KR0O2tqu7pg': "While it's a solid option, it remains lesser-known and does not offer much visual allure."}},
#  'QZqj0zcaOXV63mVVVLAhhQ': {'kw': ['place',
#    'bar',
#    'items',
#    'steak',
#    'desserts'],
#   'candidate': ['vVqxGrqt5ALxQjJGnntpKQ',
#    'Rwzp59f3Ia-v2V8Ku0zZWQ',
#    'VEy3-SnvsKgWfGM_b2irbA',
#    'n2CnBRKK82cWZ9a2OjS2xQ',
#    'f6SN9YUSpb9AjS4hnFgyxg'],
#   'explanation': {'vVqxGrqt5ALxQjJGnntpKQ': 'This restaurant offers a vibrant bar scene, excellent steak options, and a delectable dessert menu, fitting all user preferences.',
#    'Rwzp59f3Ia-v2V8Ku0zZWQ': 'Known for its quality steaks and a cozy bar atmosphere, it ranks high but slightly below the top option due to less focus on dessert.',
#    'VEy3-SnvsKgWfGM_b2irbA': 'While it provides a nice bar and decent menu items, its steak offerings are not as strong, placing it lower in the ranking.',
#    'n2CnBRKK82cWZ9a2OjS2xQ': 'Features some bar options and a limited steak selection, making it less appealing for the user’s specific desires.',
#    'f6SN9YUSpb9AjS4hnFgyxg': 'Although it may have some items, its overall menu lacks focus on steak and desserts, placing it at the bottom of the list.'}},
#  'J-NdrqdYuaBZnD8zo9pgjg': {'kw': ['place',
#    'sandwiches',
#    'dinner',
#    'lot',
#    'batter'],
#   'candidate': ['Rwzp59f3Ia-v2V8Ku0zZWQ',
#    'J9rMt_V1NX49rU3YUjh_7Q',
#    'I1wArJIYbFl2txUL6unC6A',
#    '_HMiq7vSET4uhNScBdOJnw'],
#   'explanation': {'Rwzp59f3Ia-v2V8Ku0zZWQ': 'It is known for its extensive sandwich menu, making it ideal for dinner and accommodating various preferences.',
#    'J9rMt_V1NX49rU3YUjh_7Q': 'This restaurant offers a good variety of sandwiches and a casual atmosphere for dinner.',
#    'I1wArJIYbFl2txUL6unC6A': 'While it serves sandwiches, its selection is limited compared to the top two.',
#    '_HMiq7vSET4uhNScBdOJnw': "It has the least focus on sandwiches, making it the least favorable option for the user's preferences."}},
#  'XsIVj_AszmnnsykBrKgdHw': {'kw': ['place',
#    'ingredients',
#    'meat',
#    'desserts',
#    'people'],
#   'candidate': ['NbQH02mMYJ4r1RqvG2FDBA',
#    'YnnYwfMEeSru_cJ_qKeofw',
#    'x44o1_Dw4QsQZRtBJgwZaA',
#    'wxf-tyEbFaatpJL-43JJpQ',
#    'hSEGyy0-i1_ZXGIRySbgcg'],
#   'explanation': {'NbQH02mMYJ4r1RqvG2FDBA': 'Known for its fresh ingredients and wide variety of meat dishes, along with delicious desserts.',
#    'YnnYwfMEeSru_cJ_qKeofw': 'Offers high-quality meat options and has a strong dessert menu, attracting groups of diners.',
#    'x44o1_Dw4QsQZRtBJgwZaA': "Provides a decent selection of meats and ingredients, but its dessert options aren't as strong as the top two.",
#    'wxf-tyEbFaatpJL-43JJpQ': 'Features a good variety but lacks the standout meat and dessert offerings found in higher-ranked restaurants.',
#    'hSEGyy0-i1_ZXGIRySbgcg': "Although it has a unique theme, its ingredients and meat choices don't cater well to the user’s preferences."}},
#  'ok0fpB6QHkSUpTQpO3UAfA': {'kw': ['place',
#    'edge',
#    'dinner',
#    'dish',
#    'friends'],
#   'candidate': ['Rwzp59f3Ia-v2V8Ku0zZWQ',
#    'fqhahiKsc6gPs5Sx4mf9Vg',
#    'Pv0P0vYFIOlMPPfn18Wc7Q',
#    'vVqxGrqt5ALxQjJGnntpKQ'],
#   'explanation': {'Rwzp59f3Ia-v2V8Ku0zZWQ': 'This restaurant offers a vibrant atmosphere and a range of dishes ideal for sharing with friends.',
#    'fqhahiKsc6gPs5Sx4mf9Vg': 'Known for its unique edge in cuisine, this spot is perfect for a fun dinner outing with a group.',
#    'Pv0P0vYFIOlMPPfn18Wc7Q': 'While still a good place, it may not provide the same level of social ambiance as the top choices.',
#    'vVqxGrqt5ALxQjJGnntpKQ': 'This restaurant is solid but does not specialize in shareable dishes, making it less suitable for a friendly dinner.'}},
#  'gekp2Z5I4vPGf2NeFnZX2A': {'kw': ['place', 'dinner', 'lot', 'dish', 'meat'],
#   'candidate': ['3n_2L-oqqw6noFKsb3qmeg',
#    '7LFdimtQU3yrgiKyE53klQ',
#    'YnnYwfMEeSru_cJ_qKeofw',
#    'txwpCDw5Utu9WbM0VtYJqg',
#    'ZhJ59SFPifQiTW0gAddfGw'],
#   'explanation': {'3n_2L-oqqw6noFKsb3qmeg': "This restaurant offers a wide variety of meat dishes suitable for dinner, making it ideal for the user's preferences.",
#    '7LFdimtQU3yrgiKyE53klQ': 'Known for its hearty portions and diverse meat options, this restaurant ranks highly for providing satisfying dinner experiences.',
#    'YnnYwfMEeSru_cJ_qKeofw': "Offers a good selection of meat dishes and has a cozy ambiance suitable for dinner, maintaining relevance to the user's needs.",
#    'txwpCDw5Utu9WbM0VtYJqg': 'While it has decent meat offerings, it lacks the extensive quantity preferred by the user for dinner.',
#    'ZhJ59SFPifQiTW0gAddfGw': "This restaurant is lower on the list due to limited meat options, which may not satisfy the user's request for meat-focused dishes."}},
#  'JXrx-kwCSuf1xCkwuv0Nfw': {'kw': ['place',
#    'truffle oil',
#    'fries',
#    'side',
#    'meat'],
#   'candidate': ['f6SN9YUSpb9AjS4hnFgyxg',
#    'l5lEOq47ne-jWKl67VKwZA',
#    'kA5pZz-koXIlPaDJALDroQ',
#    'ib_206uhcdzV7lNcCpniXA',
#    'ko4q1Oj4iWvYSxoamlcEgw'],
#   'explanation': {'f6SN9YUSpb9AjS4hnFgyxg': 'Offers a robust menu featuring truffle oil and fries, making it a top match for meat lovers.',
#    'l5lEOq47ne-jWKl67VKwZA': 'Features a great variety of sides and meat options, with some dishes incorporating truffle oil.',
#    'kA5pZz-koXIlPaDJALDroQ': 'Known for its excellent fries and solid meat choices, although truffle oil is a less frequent feature.',
#    'ib_206uhcdzV7lNcCpniXA': 'While it has good meat options, it lacks side dishes and the signature truffle oil flavor.',
#    'ko4q1Oj4iWvYSxoamlcEgw': "Primarily focused on unique flavors but doesn't emphasize the requested elements as much as the others."}},
#  'FQZZsU3J88IGF8n5e3XYZg': {'kw': ['place', 'dinner', 'lot', 'bunch', 'dish'],
#   'candidate': ['Rl318hUrGlkPJhMmNNZizQ',
#    'P-X4kr5pDqXzhPEfa6RsTQ',
#    'ko4q1Oj4iWvYSxoamlcEgw',
#    '_HMiq7vSET4uhNScBdOJnw',
#    'I1wArJIYbFl2txUL6unC6A'],
#   'explanation': {'Rl318hUrGlkPJhMmNNZizQ': 'This restaurant features a diverse menu perfect for dinner with a satisfying selection of dishes.',
#    'P-X4kr5pDqXzhPEfa6RsTQ': 'Known for its ample seating and variety, this place can accommodate large groups looking for a fun dinner experience.',
#    'ko4q1Oj4iWvYSxoamlcEgw': "Offers a good selection of dishes, but doesn't have as much variety as the top two options.",
#    '_HMiq7vSET4uhNScBdOJnw': 'While it has good food, it’s less suited for large gatherings compared to those ranked higher.',
#    'I1wArJIYbFl2txUL6unC6A': 'This option ranks last due to its limited dish variety for dinner and smaller dining space.'}},
#  'UwWtpjalT2xlJyglRRITug': {'kw': ['place', 'dinner', 'lot', 'dish', 'hours'],
#   'candidate': ['BYwoAKKtdSeylSN7QV8oNw',
#    '7LFdimtQU3yrgiKyE53klQ',
#    'Ku333V1F3_9MVKUJ72_ZBw',
#    '_HMiq7vSET4uhNScBdOJnw',
#    'x44o1_Dw4QsQZRtBJgwZaA'],
#   'explanation': {'BYwoAKKtdSeylSN7QV8oNw': 'This restaurant is recommended first due to its diverse dinner options and flexible hours.',
#    '7LFdimtQU3yrgiKyE53klQ': 'Ranked second as it offers a broad range of dishes, making it a great choice for dinner.',
#    'Ku333V1F3_9MVKUJ72_ZBw': 'This one is notable for its operational hours and decent selection, suitable for a casual dinner.',
#    '_HMiq7vSET4uhNScBdOJnw': 'Previously ranked higher, but it has narrower options for dinner, placing it lower.',
#    'x44o1_Dw4QsQZRtBJgwZaA': 'This restaurant offers limited hours and fewer dish varieties, making it the least preferred option.'}},
#  'uOTNLX7v8MyEikB1yVux3Q': {'kw': ['place',
#    'dinner',
#    'group',
#    'friends',
#    'side'],
#   'candidate': ['9R5laAm5Kv4aBLVtH1gVnA',
#    'txwpCDw5Utu9WbM0VtYJqg',
#    'I1wArJIYbFl2txUL6unC6A',
#    'MPzZuWpKpeLBa833zzL9IQ',
#    'ZSpfF89JnQN6fiS8OhBlZQ'],
#   'explanation': {'9R5laAm5Kv4aBLVtH1gVnA': 'This restaurant has a vibrant atmosphere perfect for groups and offers shareable side dishes that friends can enjoy together.',
#    'txwpCDw5Utu9WbM0VtYJqg': 'Known for its delicious sides and group-friendly dining options, this spot allows for a relaxed dinner experience with friends.',
#    'I1wArJIYbFl2txUL6unC6A': 'Offers a good variety of dishes suitable for sharing, making it a great option for friends dining together.',
#    'MPzZuWpKpeLBa833zzL9IQ': 'While a solid choice, it may not cater as well to large groups seeking a lively dining environment.',
#    'ZSpfF89JnQN6fiS8OhBlZQ': 'Although it provides good food, it’s more suited for quieter meals and may lack the group-friendly atmosphere desired for dinner with friends.'}},
#  'sZ3mumX9WjJqp6qrjPPUBQ': {'kw': ['place',
#    'bar',
#    'sandwiches',
#    'dinner',
#    'lot'],
#   'candidate': ['lE9qVePgvolkhw6C3Cdkeg',
#    'T7ekp7FiffoWDq53hbZDhg',
#    '_HMiq7vSET4uhNScBdOJnw',
#    'YkVRDcEa7vZK65u-tlL9tQ'],
#   'explanation': {'lE9qVePgvolkhw6C3Cdkeg': 'This restaurant has a vibrant bar scene and offers a variety of sandwiches suitable for dinner.',
#    'T7ekp7FiffoWDq53hbZDhg': "Known for its lively atmosphere and good selection of sandwiches, it's a great choice for a dinner outing.",
#    '_HMiq7vSET4uhNScBdOJnw': 'While it also caters to dinner, it lacks the bar atmosphere that enhances the dining experience.',
#    'YkVRDcEa7vZK65u-tlL9tQ': "This restaurant is less focused on sandwiches and bar options compared to the others, which may not meet the user's preferences as closely."}},
#  'g8VcsAZyMrak3vdrLr3b7w': {'kw': ['place',
#    'dinner',
#    'group',
#    'friends',
#    'meat'],
#   'candidate': ['JHi4LCxdbpXthg98sQiicQ',
#    'rXhvV-YyZaJLjgOnz7_jkA',
#    'tz8VEeIOoM5Cu1NSnC2JIQ',
#    '_HMiq7vSET4uhNScBdOJnw'],
#   'explanation': {'JHi4LCxdbpXthg98sQiicQ': 'This restaurant is known for its vibrant atmosphere and hearty meat options, making it ideal for a fun group dinner.',
#    'rXhvV-YyZaJLjgOnz7_jkA': 'Offers a diverse meat menu with ample seating, great for groups looking to enjoy different dishes together.',
#    'tz8VEeIOoM5Cu1NSnC2JIQ': 'Though it has good meat options, its atmosphere is slightly less suited for a lively group dinner compared to the top choices.',
#    '_HMiq7vSET4uhNScBdOJnw': 'While excellent for smaller gatherings, it may not accommodate larger groups as comfortably as the others.'}},
#  '1tQfj737uhgdKcQ-5akTdA': {'kw': ['place', 'dinner', 'lot', 'dish', 'spices'],
#   'candidate': ['M-PobdAR2gJhPyLR_WzMCQ',
#    'OExxlOVjUIDh3TFjPzbSDA',
#    '58PYKm0WgNunAzuS4Qu1Zg',
#    '7LFdimtQU3yrgiKyE53klQ',
#    'qs6gA9Y5sRzpXnm_4QaP0Q'],
#   'explanation': {'M-PobdAR2gJhPyLR_WzMCQ': 'This restaurant is known for its extensive menu rich in exotic spices, making it perfect for a flavorful dinner experience.',
#    'OExxlOVjUIDh3TFjPzbSDA': 'A great option for a sit-down dinner with plenty of space and a diverse selection of dishes that feature bold flavors.',
#    '58PYKm0WgNunAzuS4Qu1Zg': "While it offers good dishes, it doesn't provide as much variety in spices as the top two options.",
#    '7LFdimtQU3yrgiKyE53klQ': 'This restaurant has a cozy atmosphere but is slightly less known for its spiced offerings compared to the higher-ranked options.',
#    'qs6gA9Y5sRzpXnm_4QaP0Q': "Although it has good food, the lack of a variety of spice-rich dishes makes it less suitable for the user's specific preferences."}},
#  '1UZs_9wFHP4NR_62LwGD6g': {'kw': ['place',
#    'shop',
#    'sandwiches',
#    'dinner',
#    'lot'],
#   'candidate': ['MPzZuWpKpeLBa833zzL9IQ',
#    'x0Pk5Uvy0y63FSzcfmxRpQ',
#    'vVqxGrqt5ALxQjJGnntpKQ',
#    '_HMiq7vSET4uhNScBdOJnw',
#    '_7nMWBmfFvk9S3tKG3Ip_g'],
#   'explanation': {'MPzZuWpKpeLBa833zzL9IQ': 'This restaurant offers a robust selection of sandwiches suitable for dinner and has a welcoming atmosphere.',
#    'x0Pk5Uvy0y63FSzcfmxRpQ': 'Known for its diverse sandwich choices and casual dining experience, making it a great fit for dinner.',
#    'vVqxGrqt5ALxQjJGnntpKQ': 'This spot provides hearty sandwiches and is ideal for dinner with friends or family, though slightly less extensive in variety.',
#    '_HMiq7vSET4uhNScBdOJnw': 'Offers some sandwich options but is more limited in dinner seating, placing it lower in the ranking.',
#    '_7nMWBmfFvk9S3tKG3Ip_g': 'While it may have good sandwiches, it lacks the dinner vibe and variety that the user prefers.'}},
#  'TUAiW8Lcdla5Ii53kV6RFw': {'kw': ['place',
#    'sandwiches',
#    'dinner',
#    'lot',
#    'group'],
#   'candidate': ['VEy3-SnvsKgWfGM_b2irbA',
#    'NbQH02mMYJ4r1RqvG2FDBA',
#    '5LMkTnMXOxlce_LwUNhpCQ',
#    'J3ijSN86u_Pg42BZjkDM_g',
#    'EqdAzi9c5xuhxN9brmEaZw.'],
#   'explanation': {'VEy3-SnvsKgWfGM_b2irbA': 'This place offers a spacious setting perfect for groups and a variety of sandwich options for dinner.',
#    'NbQH02mMYJ4r1RqvG2FDBA': 'Known for its delicious sandwiches and a casual atmosphere suitable for larger gatherings during dinner time.',
#    '5LMkTnMXOxlce_LwUNhpCQ': 'A popular spot for sandwiches, though slightly smaller in capacity for groups compared to the top two.',
#    'J3ijSN86u_Pg42BZjkDM_g': 'Offers a decent sandwich selection, but lacks the atmosphere for larger groups and is better suited for smaller parties.',
#    'EqdAzi9c5xuhxN9brmEaZw': "While it has good food, it's not ideal for groups during dinner as space may be limited."}},
#  'ZNyfGsIwsedPlpjmoaq3Eg': {'kw': ['place',
#    'instagram',
#    'bar',
#    'dinner',
#    'lot'],
#   'candidate': ['Rwzp59f3Ia-v2V8Ku0zZWQ',
#    '5RFNZZvtfF9uHVSUeYwzbQ',
#    'txwpCDw5Utu9WbM0VtYJqg',
#    'x44o1_Dw4QsQZRtBJgwZaA'],
#   'explanation': {'Rwzp59f3Ia-v2V8Ku0zZWQ': 'Known for its lively atmosphere and visually appealing dishes, making it perfect for Instagram.',
#    '5RFNZZvtfF9uHVSUeYwzbQ': 'Offers a great bar selection with a vibrant dinner vibe, appealing to social media enthusiasts.',
#    'txwpCDw5Utu9WbM0VtYJqg': 'Provides a nice dinner experience but lacks the strong Instagram presence compared to the top two.',
#    'x44o1_Dw4QsQZRtBJgwZaA': 'While decent, it ranks lower due to less of an emphasis on bar culture and social media appeal.'}},
#  'Jd4LuJ2nCNBMayehLhhL4w': {'kw': ['place',
#    'dinner',
#    'steak',
#    'dessert',
#    'people'],
#   'candidate': ['P7-GGakh0UR80xIl93t07Q',
#    'x44o1_Dw4QsQZRtBJgwZaA',
#    'VEy3-SnvsKgWfGM_b2irbA',
#    'NAsglQPCdPMJV_RkHge27A',
#    'hSEGyy0-i1_ZXGIRySbgcg'],
#   'explanation': {'P7-GGakh0UR80xIl93t07Q': 'This restaurant is highly rated for its steak offerings and has a reputation for excellent desserts, making it ideal for dinner with friends or family.',
#    'x44o1_Dw4QsQZRtBJgwZaA': 'This spot provides a fantastic steak experience and is known for its inviting atmosphere, perfect for social gatherings.',
#    'VEy3-SnvsKgWfGM_b2irbA': "While it does offer great steak options, it's slightly lower on the dessert front but still a solid choice for dinner.",
#    'NAsglQPCdPMJV_RkHge27A': "This restaurant is known for a good steak but is better suited for smaller groups, which may not align fully with the user's preference for a place to enjoy with more people.",
#    'hSEGyy0-i1_ZXGIRySbgcg': 'Although it has some decent offerings, it ranks lower due to a weaker selection of steak and dessert options compared to the others.'}},
#  'I0Ml519BP2Ya3-Ec5GgVgA': {'kw': ['place', 'shop', 'bar', 'dinner', 'bunch'],
#   'candidate': ['MqdAYfl1p_c1144i48k6jw',
#    'J9rMt_V1NX49rU3YUjh_7Q',
#    'BYwoAKKtdSeylSN7QV8oNw',
#    'xpHn6SAJ3xqJGgzZTASrSg',
#    'vVqxGrqt5ALxQjJGnntpKQ'],
#   'explanation': {'MqdAYfl1p_c1144i48k6jw': "Ranked highest for its strong focus on dinner offerings, making it ideal for the user's dining preference.",
#    'J9rMt_V1NX49rU3YUjh_7Q': 'Also features robust dinner options, with a good atmosphere for evening meals.',
#    'BYwoAKKtdSeylSN7QV8oNw': 'A decent choice for dinner but slightly less appealing compared to the top two.',
#    'xpHn6SAJ3xqJGgzZTASrSg': 'More of a casual spot, not fully aligning with a sit-down dinner preference.',
#    'vVqxGrqt5ALxQjJGnntpKQ': 'Least relevant for dinner compared to others, more suited for a casual bar experience.'}},
#  'dpKkBNCSrXgwgqqXd5JqOw': {'kw': ['place', 'bar', 'lot', 'hours', 'waiter'],
#   'candidate': ['vVqxGrqt5ALxQjJGnntpKQ',
#    'ymAw53bQVppVV7T40fNgRw',
#    'ahlZC7XOKN-XJ7P4sPZrRg',
#    'bjL1PC2e9dvjBVewmoXYwQ',
#    'x44o1_Dw4QsQZRtBJgwZaA'],
#   'explanation': {'vVqxGrqt5ALxQjJGnntpKQ': 'This restaurant has excellent parking facilities, a vibrant bar, and highly rated waitstaff.',
#    'ymAw53bQVppVV7T40fNgRw': 'Known for a good selection of drinks at the bar and convenient hours, it ranks high for sociability.',
#    'ahlZC7XOKN-XJ7P4sPZrRg': 'Offers good waiter service and decent parking, but lacks a bar, slightly lowering its rank.',
#    'bjL1PC2e9dvjBVewmoXYwQ': 'While it has favorable hours and service, the absence of a bar and limited parking options affect its appeal.',
#    'x44o1_Dw4QsQZRtBJgwZaA': 'This restaurant has the least appeal based on user preferences due to poor parking and waitstaff reviews.'}},
#  'cfDwnBtcWi0Bm40lQUHCMg': {'kw': ['place',
#    'bar',
#    'people',
#    'service',
#    'food'],
#   'candidate': ['ahlZC7XOKN-XJ7P4sPZrRg',
#    'kA5pZz-koXIlPaDJALDroQ',
#    'd3vB2tlgTEapMU_kGiXRoQ',
#    'J9rMt_V1NX49rU3YUjh_7Q',
#    'pnjp8dim5eVWHIX7oYnEbQ.'],
#   'explanation': {'ahlZC7XOKN-XJ7P4sPZrRg': 'This restaurant is known for its vibrant bar atmosphere and exceptional service, making it a great place for social gatherings.',
#    'kA5pZz-koXIlPaDJALDroQ': 'While also offering a lively setting, it ranks slightly lower due to less focus on food compared to the top choice.',
#    'd3vB2tlgTEapMU_kGiXRoQ': "Offers good food and service, though the atmosphere isn't as lively as the top two.",
#    'J9rMt_V1NX49rU3YUjh_7Q': 'Generally good service, but the ambiance and crowd are more subdued, making it less appealing for socializing.',
#    'pnjp8dim5eVWHIX7oYnEbQ': 'Although it has decent food, it doesn’t meet the user’s social dynamics as effectively as the others.'}},
#  '5GUadxRaN73Jf0fdhaVCFw': {'kw': ['place',
#    'bar',
#    'dinner',
#    'service',
#    'vegetables'],
#   'candidate': ['T7ekp7FiffoWDq53hbZDhg',
#    'AQEEH7JP1DFrvFuMi6TP2Q',
#    'Pv0P0vYFIOlMPPfn18Wc7Q',
#    'M3L6py5NM0_WjIT7410M0Q',
#    'f6SN9YUSpb9AjS4hnFgyxg'],
#   'explanation': {'T7ekp7FiffoWDq53hbZDhg': 'This restaurant stands out for its vibrant bar scene and extensive vegetable-based menu, alongside excellent service.',
#    'AQEEH7JP1DFrvFuMi6TP2Q': 'Known for a cozy atmosphere and solid vegetable options, it has good service but is less lively than the top choice.',
#    'Pv0P0vYFIOlMPPfn18Wc7Q': 'A good dinner spot with decent vegetable selections and acceptable service but lacks a strong bar experience.',
#    'M3L6py5NM0_WjIT7410M0Q': 'While it serves a variety of dishes, the focus on vegetables is weaker, and the bar is less appealing.',
#    'f6SN9YUSpb9AjS4hnFgyxg': "This place offers a limited selection of vegetables and may not meet the user's preference for a bar setting."}},
#  '2zlt0VIv60yPKkCZ9TuHEg': {'kw': ['place', 'top', 'rice', 'meal', 'taste'],
#   'candidate': ['CdAmgWWCabZQoYNNWOKcEw',
#    'ZhJ59SFPifQiTW0gAddfGw',
#    'fY1IkBnRft1KR0O2tqu7pg',
#    'KPrdWch1680ihzVe3C-s3w',
#    'hSEGyy0-i1_ZXGIRySbgcg'],
#   'explanation': {'CdAmgWWCabZQoYNNWOKcEw': 'This restaurant excels in flavorful rice dishes and has received high praise for its taste.',
#    'ZhJ59SFPifQiTW0gAddfGw': 'Known for its unique rice combinations and savory meals, this place ranks high for taste.',
#    'fY1IkBnRft1KR0O2tqu7pg': 'While popular, it offers a more limited rice selection compared to the top two.',
#    'KPrdWch1680ihzVe3C-s3w': 'This restaurant has good options but lacks the standout rice dish that others provide.',
#    'hSEGyy0-i1_ZXGIRySbgcg': 'Although well-rated, it prioritizes other cuisines that may not align fully with rice-focused meals.'}},
#  '9tliQ8H9xcGN8iVl55nx_g': {'kw': ['place',
#    'instagram',
#    'bar',
#    'dinner',
#    'lot'],
#   'candidate': ['Rwzp59f3Ia-v2V8Ku0zZWQ',
#    'NbQH02mMYJ4r1RqvG2FDBA',
#    'Pv0P0vYFIOlMPPfn18Wc7Q',
#    'T7ekp7FiffoWDq53hbZDhg'],
#   'explanation': {'Rwzp59f3Ia-v2V8Ku0zZWQ': 'This restaurant offers a lively bar scene and is visually appealing for Instagram, making it ideal for your preferences.',
#    'NbQH02mMYJ4r1RqvG2FDBA': 'A great spot for dinner with a robust atmosphere that is also Instagram-friendly, although it might be slightly less spacious than the top choice.',
#    'Pv0P0vYFIOlMPPfn18Wc7Q': 'Offers decent ambiance and is a good choice for dinner but lacks the same level of Instagrammable aspects compared to the top two.',
#    'T7ekp7FiffoWDq53hbZDhg': 'While it has a nice setting, it does not offer the social or bar elements that align with your preferences as effectively as the others.'}},
#  'YUB60ublKhL0N3sMMYh6aQ': {'kw': ['place',
#    'friends',
#    'food',
#    'great place',
#    'price'],
#   'candidate': ['tRPHSd0ow1hsqMRxyMePeg',
#    'AQEEH7JP1DFrvFuMi6TP2Q',
#    '0UVlw30JrYGl79rT0XIEmw',
#    'BYwoAKKtdSeylSN7QV8oNw',
#    'I1wArJIYbFl2txUL6unC6A'],
#   'explanation': {'tRPHSd0ow1hsqMRxyMePeg': 'This restaurant offers a vibrant atmosphere and a menu that is both affordable and appealing for food-sharing among friends.',
#    'AQEEH7JP1DFrvFuMi6TP2Q': 'A good place for groups, with reasonably priced options that are sure to please a crowd.',
#    '0UVlw30JrYGl79rT0XIEmw': 'While still a solid choice, it is a bit pricier compared to the top two, making it less ideal for budget-conscious group outings.',
#    'BYwoAKKtdSeylSN7QV8oNw': 'This place has great food but lacks the lively ambiance that enhances social dining experiences.',
#    'I1wArJIYbFl2txUL6unC6A': 'Although it offers good food, it is more expensive and less suitable for larger groups compared to the others.'}},
#  'OKbv3KDqjEmYQeADqevsnA': {'kw': ['place',
#    'dinner',
#    'lot',
#    'dish',
#    'friends'],
#   'candidate': ['i5dxKKLe2kJ8WbPUXilPGg',
#    'ib_206uhcdzV7lNcCpniXA',
#    'xD3L3JhNxsAfQikOHWHa4w',
#    'x0Pk5Uvy0y63FSzcfmxRpQ'],
#   'explanation': {'i5dxKKLe2kJ8WbPUXilPGg': 'This restaurant offers a spacious dining area ideal for groups and serves a wide variety of dishes perfect for sharing.',
#    'ib_206uhcdzV7lNcCpniXA': 'Known for its ample seating and diverse menu, making it great for friends enjoying dinner together.',
#    'xD3L3JhNxsAfQikOHWHa4w': 'While a bit smaller, it still caters well to groups and has a delightful selection of dishes.',
#    'x0Pk5Uvy0y63FSzcfmxRpQ': 'Though it has some good options, it lacks the space and variety needed for an ideal group dinner setting.'}},
#  'evIjahgjJHGsuunzD9aT1A': {'kw': ['place',
#    'service',
#    'food',
#    'drinks',
#    'menu'],
#   'candidate': ['5RFNZZvtfF9uHVSUeYwzbQ',
#    '5LMkTnMXOxlce_LwUNhpCQ',
#    'I1wArJIYbFl2txUL6unC6A',
#    '6xx2FpMxjwabEHz_t2MiZg',
#    'wyDfBs1tYSIiBO7HCPKNTg.'],
#   'explanation': {'5RFNZZvtfF9uHVSUeYwzbQ': 'This restaurant excels in ambiance and service, providing a great overall dining experience.',
#    '5LMkTnMXOxlce_LwUNhpCQ': 'Known for its unique menu and quality food, it stands out for a memorable meal.',
#    'I1wArJIYbFl2txUL6unC6A': 'Offers a good variety of drinks, but the food consistency is slightly less reliable.',
#    '6xx2FpMxjwabEHz_t2MiZg': 'Competitive in service, but lacks the menu innovation and vibe of the top choices.',
#    'wyDfBs1tYSIiBO7HCPKNTg': 'Provides decent food and service, but does not match the overall experience of the others.'}},
#  'HUodv8WGv4xo7EabaN3dqQ': {'kw': ['place',
#    'sandwiches',
#    'dinner',
#    'items',
#    'group'],
#   'candidate': ['txwpCDw5Utu9WbM0VtYJqg',
#    'Rwzp59f3Ia-v2V8Ku0zZWQ',
#    '_HMiq7vSET4uhNScBdOJnw',
#    'J9rMt_V1NX49rU3YUjh_7Q',
#    '_7nMWBmfFvk9S3tKG3Ip_g'],
#   'explanation': {'txwpCDw5Utu9WbM0VtYJqg': 'This restaurant has a comprehensive sandwich menu ideal for groups and offers a vibrant place for dinner.',
#    'Rwzp59f3Ia-v2V8Ku0zZWQ': 'It provides good sandwich options and has a suitable atmosphere for group dining, making it a strong second choice.',
#    '_HMiq7vSET4uhNScBdOJnw': 'Offers a decent variety of sandwiches, but the group accommodations are slightly limited compared to the top two.',
#    'J9rMt_V1NX49rU3YUjh_7Q': "While it's good for dinner, the sandwich selection is less varied, making it less favorable for the user's preferences.",
#    '_7nMWBmfFvk9S3tKG3Ip_g': 'Although it has good items, it doesn’t specialize in sandwiches or provide the best group dining experience, placing it last.'}},
#  '9QDWLRxdU6uOscehvVt6Tw': {'kw': ['place',
#    'items',
#    'sweetness',
#    'dessert',
#    'service'],
#   'candidate': ['vVqxGrqt5ALxQjJGnntpKQ',
#    'jLcBOqa-UT6qugFgZqjNvA',
#    'IC15vAUX4EiMlWxxMehohw',
#    'Rwzp59f3Ia-v2V8Ku0zZWQ'],
#   'explanation': {'vVqxGrqt5ALxQjJGnntpKQ': 'This restaurant excels in providing a great place ambiance and has a diverse menu with a focus on desserts, making it a top choice.',
#    'jLcBOqa-UT6qugFgZqjNvA': 'Known for excellent service and a selection of sweet items, it ranks high for dessert lovers.',
#    'IC15vAUX4EiMlWxxMehohw': 'While it has decent items and service, it lacks the dessert variety to compete with the top two.',
#    'Rwzp59f3Ia-v2V8Ku0zZWQ': "It falls to the bottom as it doesn't fully meet the user's preferences concerning sweetness and a pleasant dining atmosphere."}},
#  'MmJ-gKRi3hRzBlVqEUEkOg': {'kw': ['place',
#    'lunch time',
#    'dish',
#    'friends',
#    'try'],
#   'candidate': ['WdgQzBYDtTgcLahHvtiokA',
#    'U3i7AaegudvpmDL23_wEmQ',
#    'xD3L3JhNxsAfQikOHWHa4w',
#    '58PYKm0WgNunAzuS4Qu1Zg',
#    'CfFGKTJ1RgdTYpY0fj1E5w'],
#   'explanation': {'WdgQzBYDtTgcLahHvtiokA': 'This restaurant offers a friendly atmosphere ideal for lunching with friends and a diverse menu.',
#    'U3i7AaegudvpmDL23_wEmQ': 'Known for its great lunch specials, this spot is perfect for trying out new dishes with the group.',
#    'xD3L3JhNxsAfQikOHWHa4w': "A cozy place with a well-rounded menu that's perfect for a casual midday meal.",
#    '58PYKm0WgNunAzuS4Qu1Zg': 'While traditionally known for dinner, it does offer interesting lunch options making it worth considering.',
#    'CfFGKTJ1RgdTYpY0fj1E5w': 'Although a strong contender, it is more suited for dinners and may not be as lively during lunchtime for groups of friends.'}},
#  'j8UlPZDO6K5iI8T7LKPqEA': {'kw': ['place',
#    'shop',
#    'lunch time',
#    'items',
#    'group'],
#   'candidate': ['J9rMt_V1NX49rU3YUjh_7Q',
#    'at7wfECnjgIJi5o7gL8fyQ',
#    'j_aIYB4uGOR45jAXivFNZQ',
#    'cEX4Cw8q2ftBrbpCvInf0w'],
#   'explanation': {'J9rMt_V1NX49rU3YUjh_7Q': 'This restaurant is ideal for a large group looking for a varied lunch menu and a lively atmosphere.',
#    'at7wfECnjgIJi5o7gL8fyQ': 'A great choice for lunch with convenient takeout options, perfect for those short on time.',
#    'j_aIYB4uGOR45jAXivFNZQ': 'Offers a unique menu but is less suitable for larger groups or peak lunch times.',
#    'cEX4Cw8q2ftBrbpCvInf0w': "While a solid choice overall, it doesn't cater as well to group dining compared to the higher-ranked options."}},
#  '0gBy-cIXe0DQKhFjifu68Q': {'kw': ['place', 'bar', 'group', 'bunch', 'dish'],
#   'candidate': ['T7ekp7FiffoWDq53hbZDhg',
#    'O79uzVop5yqobf3bdjZzQg',
#    '7LFdimtQU3yrgiKyE53klQ',
#    'LFknVw6uTIaL-MY_RqkN7g',
#    '_HMiq7vSET4uhNScBdOJnw'],
#   'explanation': {'T7ekp7FiffoWDq53hbZDhg': 'This restaurant has a lively bar scene ideal for groups and offers a diverse menu.',
#    'O79uzVop5yqobf3bdjZzQg': 'This place is known for its great atmosphere and variety of dishes, making it group-friendly.',
#    '7LFdimtQU3yrgiKyE53klQ': 'This option provides a fun bar environment, though slightly less focus on group dining compared to the top two.',
#    'LFknVw6uTIaL-MY_RqkN7g': 'Although good for casual dining, it lacks a vibrant bar setting for larger gatherings.',
#    '_HMiq7vSET4uhNScBdOJnw': 'This restaurant is less appealing for groups seeking a bar experience or extensive dish variety.'}},
#  'FAi3gMEwxhnh9tZRQiWwTg': {'kw': ['place',
#    'group',
#    'dish',
#    'friends',
#    'waiter'],
#   'candidate': ['I1wArJIYbFl2txUL6unC6A',
#    'KmKkhD-97CqPvokq5JIoBA',
#    'uQu5DtnXZZ8XVfBKldKnag',
#    'x44o1_Dw4QsQZRtBJgwZaA',
#    '0hGE_UiUMAcF3PABcE-M4Q'],
#   'explanation': {'I1wArJIYbFl2txUL6unC6A': 'Best suited for groups with a variety of dishes and excellent service from the waitstaff.',
#    'KmKkhD-97CqPvokq5JIoBA': 'Offers a good atmosphere for friends and a solid dish selection, though service may vary.',
#    'uQu5DtnXZZ8XVfBKldKnag': 'Great for groups with a lively environment and decent dish offerings, but slightly less consistent service.',
#    'x44o1_Dw4QsQZRtBJgwZaA': 'While it has good dishes, it’s less ideal for larger groups and the service can be hit or miss.',
#    '0hGE_UiUMAcF3PABcE-M4Q': 'Typically a quieter setting with limited dish options, not as suitable for a group of friends.'}},
#  'fAY7S51J_9uMMZRVTO8f3w': {'kw': ['place',
#    'dinner',
#    'items',
#    'group',
#    'dish'],
#   'candidate': ['Rwzp59f3Ia-v2V8Ku0zZWQ',
#    '_HMiq7vSET4uhNScBdOJnw',
#    'J9rMt_V1NX49rU3YUjh_7Q',
#    'txwpCDw5Utu9WbM0VtYJqg'],
#   'explanation': {'Rwzp59f3Ia-v2V8Ku0zZWQ': 'This restaurant offers a diverse menu that is well-suited for groups, making it ideal for a dinner setting.',
#    '_HMiq7vSET4uhNScBdOJnw': 'Known for its unique and shareable dishes, this spot is perfect for a group gathering during dinner.',
#    'J9rMt_V1NX49rU3YUjh_7Q': 'Offers excellent dinner options but has a more limited menu, making it slightly less favorable for diverse group preferences.',
#    'txwpCDw5Utu9WbM0VtYJqg': "While it has great items, it's not as group-friendly for dinner compared to the others."}},
#  'a7y3gCq9Vwv89NRtUTtyJw': {'kw': ['place',
#    'other friends',
#    'edge',
#    'shop',
#    'bar'],
#   'candidate': ['J9rMt_V1NX49rU3YUjh_7Q',
#    '-WRbjOIgvQQ3jlJnvKUBNA',
#    '6xx2FpMxjwabEHz_t2MiZg',
#    '_HMiq7vSET4uhNScBdOJnw',
#    'ahlZC7XOKN-XJ7P4sPZrRg'],
#   'explanation': {'J9rMt_V1NX49rU3YUjh_7Q': 'This restaurant has a vibrant bar scene, making it ideal for socializing with friends.',
#    '-WRbjOIgvQQ3jlJnvKUBNA': 'This place offers a trendy edge and a great atmosphere for group outings.',
#    '6xx2FpMxjwabEHz_t2MiZg': 'This restaurant has a chill vibe, perfect for casual meet-ups with friends.',
#    '_HMiq7vSET4uhNScBdOJnw': 'Although good, it lacks the lively feel desired by the user, placing it lower.',
#    'ahlZC7XOKN-XJ7P4sPZrRg': 'This location is better suited for a quieter experience, which does not align with the user’s preferences.'}},
#  '1wWXchH7yRlFCxfC4dkQnA': {'kw': ['place', 'shop', 'dinner', 'lot', 'items'],
#   'candidate': ['-U4BnQL4VC3dkRDUZL0i8Q',
#    '6LgTc7CZlXCd1Pxq3BiVcw',
#    'txwpCDw5Utu9WbM0VtYJqg',
#    'Rwzp59f3Ia-v2V8Ku0zZWQ.'],
#   'explanation': {'-U4BnQL4VC3dkRDUZL0i8Q': 'This restaurant offers a spacious layout and a diverse menu, making it ideal for dinner.',
#    '6LgTc7CZlXCd1Pxq3BiVcw': 'This place has a good reputation for dinner options and a variety of dishes, though it is slightly smaller.',
#    'txwpCDw5Utu9WbM0VtYJqg': "While it has decent options, it doesn't provide the same level of space and variety as the top two.",
#    'Rwzp59f3Ia-v2V8Ku0zZWQ': 'This restaurant is less favorable in terms of items offered and overall space for a comfortable dining experience.'}},
#  'Nd-GGF74T3RKlty7PqM48A': {'kw': ['place',
#    'lot',
#    'try',
#    'broth',
#    'restaurant'],
#   'candidate': ['I1wArJIYbFl2txUL6unC6A',
#    'n5vQCdHfl2Dm7r4l5FW8Cw',
#    'CTYFfHq1SWFyCeJ-KyIgOQ',
#    'IC15vAUX4EiMlWxxMehohw'],
#   'explanation': {'I1wArJIYbFl2txUL6unC6A': 'This restaurant is known for its diverse broth options and comfortable atmosphere, making it a top choice for trying new flavors.',
#    'n5vQCdHfl2Dm7r4l5FW8Cw': 'Offers a solid variety of well-prepared broths and is appreciated for its spacious dining area.',
#    'CTYFfHq1SWFyCeJ-KyIgOQ': 'While it serves great broth, the space may not be as inviting for those who value ambiance.',
#    'IC15vAUX4EiMlWxxMehohw': 'This restaurant, although popular, has limited broth options compared to the others, which may not satisfy the user’s desire to try different kinds.'}},
#  'JxQmVUwbUBAZiji4kZtVSg': {'kw': ['place',
#    'sandwiches',
#    'dinner',
#    'lot',
#    'group'],
#   'candidate': ['sxQdEEfKRviWRymOoH9UiA',
#    'JHi4LCxdbpXthg98sQiicQ',
#    '_HMiq7vSET4uhNScBdOJnw',
#    'BYwoAKKtdSeylSN7QV8oNw',
#    'lE9qVePgvolkhw6C3Cdkeg'],
#   'explanation': {'sxQdEEfKRviWRymOoH9UiA': 'This restaurant is known for its exceptional sandwiches and has ample space for groups, making it the top choice.',
#    'JHi4LCxdbpXthg98sQiicQ': 'A solid option that provides good sandwiches and a friendly atmosphere for dinner with friends.',
#    '_HMiq7vSET4uhNScBdOJnw': 'Offers a limited sandwich menu but is set up to handle larger parties well.',
#    'BYwoAKKtdSeylSN7QV8oNw': 'Known for quality food, but the selection of sandwiches is not as extensive as desired.',
#    'lE9qVePgvolkhw6C3Cdkeg': 'While it has a great ambiance, it lacks group seating and sandwich options, placing it last.'}},
#  'qnIyZwh99Jhww8BhsfUg_w': {'kw': ['place', 'fries', 'bowl', 'price', 'sgd'],
#   'candidate': ['new3Ny6i5ZJVn3m-i4A2Tg',
#    'Eo6RtLvIXcgSge6Z4Z6fFQ',
#    'Rwzp59f3Ia-v2V8Ku0zZWQ',
#    'EJNkmXMDWurCPjOZe_WXAg',
#    'xYGH13XolFh_yiQRo7bPJQ'],
#   'explanation': {'new3Ny6i5ZJVn3m-i4A2Tg': "This restaurant offers a variety of bowls and has highly-rated fries, making it very appealing for the user's preferences.",
#    'Eo6RtLvIXcgSge6Z4Z6fFQ': 'Known for its great value and options for both bowls and fries, it ranks closely behind the top pick.',
#    'Rwzp59f3Ia-v2V8Ku0zZWQ': 'Offers decent meal options within budget and includes fries but is slightly lower in overall appeal.',
#    'EJNkmXMDWurCPjOZe_WXAg': 'While it has some bowl options, the fries are less favored, affecting its ranking negatively.',
#    'xYGH13XolFh_yiQRo7bPJQ': 'This place has limited offerings that align with the user’s preferences, making it the least favorable choice.'}},
#  '8NyAypqBJG2JiSXBu7Vlug': {'kw': ['place',
#    'dinner',
#    'friends',
#    'service',
#    'food'],
#   'candidate': ['MqdAYfl1p_c1144i48k6jw',
#    '1nw-_Bm8sivTBZ7Z-uiVCA',
#    'o1_iIC0rU2yuF3SZvf6IjA',
#    'x0Pk5Uvy0y63FSzcfmxRpQ',
#    '_HMiq7vSET4uhNScBdOJnw'],
#   'explanation': {'MqdAYfl1p_c1144i48k6jw': 'Known for its outstanding food quality and inviting atmosphere, making it perfect for friends gathering.',
#    '1nw-_Bm8sivTBZ7Z-uiVCA': 'Offers great service and a lively environment, ideal for dinner with friends.',
#    'o1_iIC0rU2yuF3SZvf6IjA': 'While it has good food, it lacks some of the ambiance desired for a social dinner.',
#    'x0Pk5Uvy0y63FSzcfmxRpQ': 'Provides decent service but is less suited for a more intimate dinner setting.',
#    '_HMiq7vSET4uhNScBdOJnw': 'Overall good, but it does not stand out compared to the others in terms of food and service for a dinner experience.'}},
#  'HO35wso-psqx0GF--QSwGA': {'kw': ['place',
#    'dinner',
#    'dish',
#    'ingredients',
#    'people'],
#   'candidate': ['Rwzp59f3Ia-v2V8Ku0zZWQ',
#    'ADtSvzL_abKwWPM1EL2yJw',
#    'BfGgttAzEPx9v7b8Sgkedw',
#    'J9rMt_V1NX49rU3YUjh_7Q'],
#   'explanation': {'Rwzp59f3Ia-v2V8Ku0zZWQ': "This restaurant features a diverse menu, aligning well with the user's interest in specific dishes and ingredient variety.",
#    'ADtSvzL_abKwWPM1EL2yJw': 'Known for its inviting atmosphere and suitable for dinner gatherings, making it a great choice for social dining.',
#    'BfGgttAzEPx9v7b8Sgkedw': 'While it has popular dishes, it lacks variety in ingredients, placing it lower on the list.',
#    'J9rMt_V1NX49rU3YUjh_7Q': "This restaurant, though previously ranked higher, does not meet the user's preferences as strongly regarding specific ingredients and dinner focus."}},
#  'jVoWhV1DT0peojYuH3HbLg': {'kw': ['place',
#    'sweetness',
#    'meat',
#    'food',
#    'broth'],
#   'candidate': ['MqdAYfl1p_c1144i48k6jw',
#    'dFYfZsc-SUwRpDEgJiIoXA',
#    '_HMiq7vSET4uhNScBdOJnw',
#    'P-X4kr5pDqXzhPEfa6RsTQ',
#    'uQu5DtnXZZ8XVfBKldKnag'],
#   'explanation': {'MqdAYfl1p_c1144i48k6jw': "This restaurant offers a strong variety of meaty dishes with a well-balanced broth, aligning well with the user's preferences.",
#    'dFYfZsc-SUwRpDEgJiIoXA': "Known for its sweet flavor profiles and hearty meat options, making it a perfect fit for the user's tastes.",
#    '_HMiq7vSET4uhNScBdOJnw': 'This place has a focus on food quality and decent broth, slightly less sweet than the top two but still satisfying.',
#    'P-X4kr5pDqXzhPEfa6RsTQ': 'While good, it does not emphasize sweetness as much, which is a key preference for the user.',
#    'uQu5DtnXZZ8XVfBKldKnag': "Ranked lowest due to a lack of emphasis on meat and broth, making it less appealing for the user's specific preferences."}},
#  'UTzUG8exwDoHDW6V0BSE2w': {'kw': ['place',
#    'side',
#    'singapore',
#    'faces',
#    'spot'],
#   'candidate': ['XuxzGu2PEr59drHseZOVCg',
#    '97DdiERj19Fuk5CRpHl0Hg',
#    'hinGqQYvot8HtRYxSdr6FA',
#    'WFtN3VJ4Tft0hQHl6NZaAA',
#    'fY1IkBnRft1KR0O2tqu7pg'],
#   'explanation': {'XuxzGu2PEr59drHseZOVCg': 'This restaurant offers a dynamic atmosphere and is known for its communal dining style, which fits the "faces" aspect well.',
#    '97DdiERj19Fuk5CRpHl0Hg': "A vibrant spot with a lively ambiance that emphasizes social interaction, ideal for the user's preferences.",
#    'hinGqQYvot8HtRYxSdr6FA': "A well-reviewed restaurant with a solid reputation, though it doesn't fully capture the vibrant experience sought by the user.",
#    'WFtN3VJ4Tft0hQHl6NZaAA': 'A popular choice, but it lacks the engaging environment the user seems to prefer.',
#    'fY1IkBnRft1KR0O2tqu7pg': 'This place has great food but may fall short in offering the lively setting desired for social dining experiences.'}},
#  '6G3tlx3-W5IH1lmaPXBSoQ': {'kw': ['place',
#    'flavour',
#    'service',
#    'food',
#    'singapore'],
#   'candidate': ['sxQdEEfKRviWRymOoH9UiA',
#    'J9rMt_V1NX49rU3YUjh_7Q',
#    '7LFdimtQU3yrgiKyE53klQ',
#    'r0bjzYPVHwZo_DP66VLt4Q',
#    'VWLfePKMEj7g2P77RvRDuA'],
#   'explanation': {'sxQdEEfKRviWRymOoH9UiA': 'This restaurant is known for its exceptional service and unique flavours that resonate well with the local palate.',
#    'J9rMt_V1NX49rU3YUjh_7Q': 'Renowned for its vibrant atmosphere and diverse menu, it draws in diners looking for local Singaporean cuisine with a twist.',
#    '7LFdimtQU3yrgiKyE53klQ': 'While still offering good food, it lacks the standout service that other top choices provide.',
#    'r0bjzYPVHwZo_DP66VLt4Q': "Although it has solid flavours, it's set in a less desirable location compared to the top options.",
#    'VWLfePKMEj7g2P77RvRDuA': 'Previously ranked higher, but it falls short on service and overall experience compared to the others on this list.'}},
#  'uSphcDFYUZW4cDBW7XPjdA': {'kw': ['place',
#    'waiter',
#    'people',
#    'singapore',
#    'price'],
#   'candidate': ['Rwzp59f3Ia-v2V8Ku0zZWQ',
#    'KmKkhD-97CqPvokq5JIoBA',
#    'J9rMt_V1NX49rU3YUjh_7Q',
#    'BYwoAKKtdSeylSN7QV8oNw',
#    'ahlZC7XOKN-XJ7P4sPZrRg'],
#   'explanation': {'Rwzp59f3Ia-v2V8Ku0zZWQ': 'Best suited for social dining with attentive waitstaff and good pricing.',
#    'KmKkhD-97CqPvokq5JIoBA': 'A close second, popular for its location and service quality.',
#    'J9rMt_V1NX49rU3YUjh_7Q': 'Offers a pleasant atmosphere for groups, making it ideal for social interactions.',
#    'BYwoAKKtdSeylSN7QV8oNw': 'Nice venue but slightly pricier, lowering its rank.',
#    'ahlZC7XOKN-XJ7P4sPZrRg': 'While a decent option, it lacks the ambiance and service engagement found in the top choices.'}},
#  '8uhSaRacb0fkPxe4re4StA': {'kw': ['place', 'lot', 'group', 'meat', 'people'],
#   'candidate': ['tz8VEeIOoM5Cu1NSnC2JIQ',
#    'JHi4LCxdbpXthg98sQiicQ',
#    'x0Pk5Uvy0y63FSzcfmxRpQ',
#    'Lv5GFFciSK532QIX2ZLqjg',
#    '_HMiq7vSET4uhNScBdOJnw'],
#   'explanation': {'tz8VEeIOoM5Cu1NSnC2JIQ': 'This restaurant has ample space for groups and features a robust meat selection, making it ideal for gatherings.',
#    'JHi4LCxdbpXthg98sQiicQ': 'Known for its spacious layout and variety of meat dishes, this place is also well-suited for larger crowds.',
#    'x0Pk5Uvy0y63FSzcfmxRpQ': "Although it offers a decent selection, it doesn't quite match the group-friendliness of the top two options.",
#    'Lv5GFFciSK532QIX2ZLqjg': 'This restaurant is more limited in space and meat choices, putting it lower in priority for group gatherings.',
#    '_HMiq7vSET4uhNScBdOJnw': "Ranked last, it lacks both room for larger groups and a variety of meat options, making it less appealing for the user's preferences."}},
#  'Z9z67ChosXkTjjNAtFmN7w': {'kw': ['place',
#    'shop',
#    'lot',
#    'dish',
#    'pulled pork'],
#   'candidate': ['_7nMWBmfFvk9S3tKG3Ip_g',
#    'EJNkmXMDWurCPjOZe_WXAg',
#    'qs6gA9Y5sRzpXnm_4QaP0Q',
#    'vVqxGrqt5ALxQjJGnntpKQ'],
#   'explanation': {'_7nMWBmfFvk9S3tKG3Ip_g': "Known for its pulled pork offerings, making it the top choice for the user's specified dish.",
#    'EJNkmXMDWurCPjOZe_WXAg': 'Offers a great variety of smoked meats including pulled pork, enhancing its ranking.',
#    'qs6gA9Y5sRzpXnm_4QaP0Q': 'While not as focused on pulled pork, it still serves quality dishes in a good setting.',
#    'vVqxGrqt5ALxQjJGnntpKQ': "Doesn't specialize in pulled pork or related dishes, placing it last in this context."}},
#  '6sRkV6dUa2TigWeVi4P9FQ': {'kw': ['place',
#    'pulled pork',
#    'steak',
#    'food',
#    'friend'],
#   'candidate': ['KPrdWch1680ihzVe3C-s3w',
#    'LFknVw6uTIaL-MY_RqkN7g',
#    'vVqxGrqt5ALxQjJGnntpKQ',
#    'Xtr2M_mh9_jOkmpNd_CSCA',
#    '6LgTc7CZlXCd1Pxq3BiVcw'],
#   'explanation': {'KPrdWch1680ihzVe3C-s3w': 'Known for its exceptional steak and barbecue options, making it a top choice for meat lovers.',
#    'LFknVw6uTIaL-MY_RqkN7g': 'Offers great pulled pork dishes that align perfectly with user preferences for high-quality food.',
#    'vVqxGrqt5ALxQjJGnntpKQ': 'A solid option with good food, but slightly less focused on the pulled pork and steak.',
#    'Xtr2M_mh9_jOkmpNd_CSCA': "A decent restaurant with variety, but doesn't specialize in the user's preferred meat dishes as highly as others.",
#    '6LgTc7CZlXCd1Pxq3BiVcw': 'Lower in rank due to less emphasis on high-quality pulled pork and steak compared to others.'}},
#  'sF0HEhcWb13p_txmssFotw': {'kw': ['place', 'meal', 'fish', 'chips', 'coffee'],
#   'candidate': ['U3i7AaegudvpmDL23_wEmQ',
#    'vZiWYH4XIiy3fqPNy615Kg',
#    'EECw-s6Jy-fyJHhkUGQhHg',
#    'NCwX8t4pHpcAMzSCaC2Hww',
#    '3vr42-TF3V31LrN5sAFbDQ'],
#   'explanation': {'U3i7AaegudvpmDL23_wEmQ': 'This restaurant excels in serving fish and chips, has a great location for a casual meal by the water, and offers decent coffee options, making it the top choice.',
#    'vZiWYH4XIiy3fqPNy615Kg': 'Known for its bustling atmosphere and solid fish and chips, this place also serves good coffee, which aligns well with user preferences.',
#    'EECw-s6Jy-fyJHhkUGQhHg': 'Offers a robust menu featuring fish and chips, but the ambiance is slightly less favorable compared to the top two options.',
#    'NCwX8t4pHpcAMzSCaC2Hww': 'While they serve tasty fish and chips, the coffee selection may not be as appealing as other spots in the list.',
#    '3vr42-TF3V31LrN5sAFbDQ': 'This restaurant is more renowned for other dishes rather than fish and chips, placing it last in the ranking despite having a good coffee menu.'}},
#  'owI_FQdAKZQFY8UnkQoD8g': {'kw': ['place',
#    'staff',
#    'coffee',
#    'point',
#    'temperature'],
#   'candidate': ['Eo87r_6a9Z3L_a8f9zVoow',
#    'eKctA6ndawB61VrmSF-dXw',
#    'NKkh6R7i2DQbUtyd5IdG_A',
#    'VZcs1K7A31sNQurNXs9gaQ'],
#   'explanation': {'Eo87r_6a9Z3L_a8f9zVoow': 'This restaurant has a vibrant atmosphere, friendly staff, and highly-rated coffee, making it a top choice.',
#    'eKctA6ndawB61VrmSF-dXw': 'Known for its cozy ambiance and attentive service, offering a solid coffee experience as well.',
#    'NKkh6R7i2DQbUtyd5IdG_A': 'Although it has decent reviews, it falls slightly short in the coffee and staff friendliness compared to the top two.',
#    'VZcs1K7A31sNQurNXs9gaQ': 'Ranked lowest due to a less favorable environment and average service, affecting overall enjoyment.'}},
#  'qnXgtXUvHRn0L0_8SirnWw': {'kw': ['place',
#    'sandwiches',
#    'dinner',
#    'group',
#    'dish'],
#   'candidate': ['x44o1_Dw4QsQZRtBJgwZaA',
#    'VEy3-SnvsKgWfGM_b2irbA',
#    'I1wArJIYbFl2txUL6unC6A',
#    'lycfBKtcR7keDQQOeMMsoA'],
#   'explanation': {'x44o1_Dw4QsQZRtBJgwZaA': 'This restaurant offers a variety of sandwiches and a spacious environment perfect for groups dining together.',
#    'VEy3-SnvsKgWfGM_b2irbA': 'Renowned for its quality sandwiches and communal dining areas, making it an excellent group choice.',
#    'I1wArJIYbFl2txUL6unC6A': 'While it has good offerings, it is slightly less accommodating for groups compared to the top two rankings.',
#    'lycfBKtcR7keDQQOeMMsoA': 'This place focuses more on other dinner options and does not emphasize sandwiches as much, placing it at the bottom of the list.'}},
#  'dBBQLSNK3xyowDow3wSQLg': {'kw': ['place',
#    'lunch time',
#    'items',
#    'facebook',
#    'desserts'],
#   'candidate': ['jLcBOqa-UT6qugFgZqjNvA',
#    '9R5laAm5Kv4aBLVtH1gVnA',
#    'YnnYwfMEeSru_cJ_qKeofw',
#    'VZcs1K7A31sNQurNXs9gaQ',
#    'CTYFfHq1SWFyCeJ-KyIgOQ'],
#   'explanation': {'jLcBOqa-UT6qugFgZqjNvA': 'This restaurant is highly rated for its lunch offerings and desserts, making it a top choice for the user.',
#    '9R5laAm5Kv4aBLVtH1gVnA': 'Known for its diverse menu and strong Facebook presence, this spot caters well to lunch diners.',
#    'YnnYwfMEeSru_cJ_qKeofw': 'Offers a good selection of lunch items and is recognized for its desserts, appealing to the user’s sweet tooth.',
#    'VZcs1K7A31sNQurNXs9gaQ': 'While it serves lunch, it has fewer dessert options compared to the top three.',
#    'CTYFfHq1SWFyCeJ-KyIgOQ': 'Although a popular place, it does not focus as much on dessert offerings, placing it lower in the rankings.'}},
#  '69BnQt-ykPsqriePrJKIqw': {'kw': ['place',
#    'shop',
#    'lunch time',
#    'dish',
#    'spices'],
#   'candidate': ['vVqxGrqt5ALxQjJGnntpKQ',
#    'BYwoAKKtdSeylSN7QV8oNw',
#    'HMiq7vSET4uhNScBdOJnw',
#    '7LFdimtQU3yrgiKyE53klQ',
#    'KPrdWch1680ihzVe3C-s3w'],
#   'explanation': {'vVqxGrqt5ALxQjJGnntpKQ': "This restaurant is known for its extensive spicy lunch menu, making it a perfect match for the user's preferences.",
#    'BYwoAKKtdSeylSN7QV8oNw': 'Offers a shop-like atmosphere and several dishes with a good balance of spices, suitable for lunch.',
#    'HMiq7vSET4uhNScBdOJnw': 'While it has some spicy dishes, the overall lunch options are less diverse than the top two.',
#    '7LFdimtQU3yrgiKyE53klQ': 'Features a nice lunch environment but lacks in the spice department compared to the higher-ranked options.',
#    'KPrdWch1680ihzVe3C-s3w': 'This restaurant focuses more on milder flavors, making it less appealing for a lunch preference that emphasizes spiciness.'}},
#  'w-hrD3-YJXbDUlvBwrpWtA': {'kw': ['place',
#    'instagram',
#    'shop',
#    'dinner',
#    'hours'],
#   'candidate': ['tz8VEeIOoM5Cu1NSnC2JIQ',
#    'vVqxGrqt5ALxQjJGnntpKQ',
#    'J9rMt_V1NX49rU3YUjh_7Q',
#    'cEX4Cw8q2ftBrbpCvInf0w',
#    'x0Pk5Uvy0y63FSzcfmxRpQ'],
#   'explanation': {'tz8VEeIOoM5Cu1NSnC2JIQ': 'This restaurant has a vibrant atmosphere ideal for Instagram, along with a dinner menu that appeals to shop-like dining.',
#    'vVqxGrqt5ALxQjJGnntpKQ': 'It offers a cozy place with great décor perfect for social media sharing, though it has slightly limited hours.',
#    'J9rMt_V1NX49rU3YUjh_7Q': 'Known for its eclectic menu, this spot has aesthetic appeal but doesn’t focus as much on a shop-like experience.',
#    'cEX4Cw8q2ftBrbpCvInf0w': 'While still enjoyable, it is more utilitarian and less visually appealing for Instagram.',
#    'x0Pk5Uvy0y63FSzcfmxRpQ': 'This restaurant ranks lowest because it lacks the ambience and charm that the user is likely seeking, plus limited evening options.'}},
# ...
#  'GxvTcyoxfR1rmd_KMWF9aw': {'kw': ['waiter',
#    'service',
#    'food',
#    'stars',
#    'staff'],
#   'candidate': ['x44o1_Dw4QsQZRtBJgwZaA',
#    'bjL1PC2e9dvjBVewmoXYwQ',
#    'I1wArJIYbFl2txUL6unC6A',
#    'vVqxGrqt5ALxQjJGnntpKQ',
#    'hSEGyy0-i1_ZXGIRySbgcg'],
#   'explanation': {'x44o1_Dw4QsQZRtBJgwZaA': 'Known for exceptional waiter attentiveness and high-quality food, making it a top choice.',
#    'bjL1PC2e9dvjBVewmoXYwQ': 'Offers excellent service and a welcoming atmosphere along with tasty dishes.',
#    'I1wArJIYbFl2txUL6unC6A': 'Provides good food and decent service, but not as strong in staff engagement.',
#    'vVqxGrqt5ALxQjJGnntpKQ': 'While the food is enjoyable, the service can be inconsistent.',
#    'hSEGyy0-i1_ZXGIRySbgcg': 'Generally decent performance, but doesn’t stand out in waiter interaction or food quality.'}},
#  'b-shuWlFnuSCeLqOeky8tA': {'kw': ['caution',
#    'singapore',
#    'menu',
#    'fruit',
#    'favorite places'],
#   'candidate': ['_HMiq7vSET4uhNScBdOJnw',
#    'sxQdEEfKRviWRymOoH9UiA',
#    '_kuDz_Uf6JbARZEfNpkl8Q',
#    'lE9qVePgvolkhw6C3Cdkeg',
#    '_e7yPjlgOAF7z8PssDamug'],
#   'explanation': {'_HMiq7vSET4uhNScBdOJnw': 'This restaurant has a well-balanced menu with several fruit-based dishes, catering to both health-conscious eaters and those who enjoy exploring diverse flavors.',
#    'sxQdEEfKRviWRymOoH9UiA': "Known for its fusion cuisine, this restaurant offers a variety of dishes featuring fruits, aligning well with the user's preferences while still being safe in flavor combinations.",
#    '_kuDz_Uf6JbARZEfNpkl8Q': 'While it has a somewhat limited menu, it includes fresh fruit options and generally maintains a cautious approach to its dishes.',
#    'lE9qVePgvolkhw6C3Cdkeg': 'This restaurant is a favorite for its consistency but lacks the variety of fruity menu items that the user prefers.',
#    '_e7yPjlgOAF7z8PssDamug': "Although it offers some safe options, it does not highlight fruits prominently enough to meet the user's specific preference."}},
#  'xFDRt8cv--y1tvEhqX_DHw': {'kw': ['total', 'food', 'times', 'table', 'wife'],
#   'candidate': ['I1wArJIYbFl2txUL6unC6A',
#    'EqdAzi9c5xuhxN9brmEaZw',
#    'hSEGyy0-i1_ZXGIRySbgcg',
#    'LFknVw6uTIaL-MY_RqkN7g',
#    'vVqxGrqt5ALxQjJGnntpKQ'],
#   'explanation': {'I1wArJIYbFl2txUL6unC6A': 'This restaurant offers a highly rated culinary experience and a romantic atmosphere, perfect for dining with your wife.',
#    'EqdAzi9c5xuhxN9brmEaZw': 'Known for its diverse and delicious menu options, this place is another great spot for couples looking to enjoy quality food together.',
#    'hSEGyy0-i1_ZXGIRySbgcg': 'Although slightly less focused on the dining atmosphere, it still provides good food and can accommodate couples well.',
#    'LFknVw6uTIaL-MY_RqkN7g': "This restaurant is solid but doesn't quite match the overall dining experience and ambiance that is preferable for a couple.",
#    'vVqxGrqt5ALxQjJGnntpKQ': 'While it has its merits, it ranks lowest due to less emphasis on the romantic dining experience and overall atmosphere.'}},
#  'BDLd6HfU_C6-6URrLRLrnw': {'kw': ['people',
#    'service',
#    'food',
#    'great place',
#    'one'],
#   'candidate': ['at7wfECnjgIJi5o7gL8fyQ',
#    'bjL1PC2e9dvjBVewmoXYwQ',
#    'Rl318hUrGlkPJhMmNNZizQ',
#    'U3i7AaegudvpmDL23_wEmQ',
#    'Dn83poKTVhWL3ItLdalmYw'],
#   'explanation': {'at7wfECnjgIJi5o7gL8fyQ': 'Offers excellent service and a vibrant atmosphere ideal for socializing.',
#    'bjL1PC2e9dvjBVewmoXYwQ': 'Known for its fantastic food and attentive staff, making it a great place to enjoy with others.',
#    'Rl318hUrGlkPJhMmNNZizQ': "Although good, it doesn't quite match the social vibe of the top two.",
#    'U3i7AaegudvpmDL23_wEmQ': 'A good place but sometimes lacks the service quality prioritized by the user.',
#    'Dn83poKTVhWL3ItLdalmYw': "This restaurant offers decent food but doesn't provide the lively atmosphere the user desires."}},
#  '6OaTrornYAPhU-M7A8wubg': {'kw': ['people',
#    'service',
#    'food',
#    'singapore',
#    'location'],
#   'candidate': ['1nw-_Bm8sivTBZ7Z-uiVCA',
#    'sxQdEEfKRviWRymOoH9UiA',
#    'CdAmgWWCabZQoYNNWOKcEw',
#    'UPRFpMsB4I64GRjUqjRmiw'],
#   'explanation': {'1nw-_Bm8sivTBZ7Z-uiVCA': 'Known for excellent service and a vibrant atmosphere, making it ideal for social dining experiences.',
#    'sxQdEEfKRviWRymOoH9UiA': 'High-quality food and service, popular among locals which enhances the social aspect.',
#    'CdAmgWWCabZQoYNNWOKcEw': 'Offers good food but slightly less emphasis on service and atmosphere compared to the top two.',
#    'UPRFpMsB4I64GRjUqjRmiw': 'While it has decent food, it falls short in service and the welcoming atmosphere preferred by the user.'}},
#  'MsNATWFEcNUtF48INY7Kig': {'kw': ['pax',
#    'service',
#    'food',
#    'singapore',
#    'staff'],
#   'candidate': ['J9rMt_V1NX49rU3YUjh_7Q',
#    'AQEEH7JP1DFrvFuMi6TP2Q',
#    'Z9oNUI_dlEKjhEWuG-hxPA',
#    'n2CnBRKK82cWZ9a2OjS2xQ',
#    'Po0Qb6X_g8b00OggqtATRA'],
#   'explanation': {'J9rMt_V1NX49rU3YUjh_7Q': 'Best reputation for service quality and consistent food excellence in Singapore.',
#    'AQEEH7JP1DFrvFuMi6TP2Q': 'Known for attentive staff and a pleasant dining atmosphere.',
#    'Z9oNUI_dlEKjhEWuG-hxPA': 'Offers a unique menu with good service, making it a popular choice.',
#    'n2CnBRKK82cWZ9a2OjS2xQ': 'Good food but slightly lacking in service compared to those ranked above.',
#    'Po0Qb6X_g8b00OggqtATRA': 'While it has decent food, service experiences have been inconsistent recently.'}},
#  'bF6PqsugCWjBZ-RVIJzrmQ': {'kw': ['service',
#    'singapore',
#    'pizza',
#    'appetite',
#    'dining'],
#   'candidate': ['NMz0wMYMTnsyC_sulMLwlA',
#    'TzKx4KbFOzLX0v7F31cSpw',
#    'MqdAYfl1p_c1144i48k6jw',
#    'NCwX8t4pHpcAMzSCaC2Hww'],
#   'explanation': {'NMz0wMYMTnsyC_sulMLwlA': 'This restaurant is known for outstanding service and has a diverse pizza menu, making it the top choice for the user.',
#    'TzKx4KbFOzLX0v7F31cSpw': 'A solid choice for pizza lovers, it also offers a comfortable dining atmosphere and good service, placing it second.',
#    'MqdAYfl1p_c1144i48k6jw': 'While it serves pizza, the service is fairly average compared to the top two, which impacts its ranking.',
#    'NCwX8t4pHpcAMzSCaC2Hww': 'This option is further down the list primarily due to less favorable service reviews despite having a reasonable food selection.'}},
#  'BbAr5pdyz1kPApiilQA2jQ': {'kw': ['service',
#    'food',
#    'singapore',
#    'great place',
#    'location'],
#   'candidate': ['_HMiq7vSET4uhNScBdOJnw',
#    'YnnYwfMEeSru_cJ_qKeofw',
#    'ahlZC7XOKN-XJ7P4sPZrRg',
#    'J9rMt_V1NX49rU3YUjh_7Q'],
#   'explanation': {'_HMiq7vSET4uhNScBdOJnw': 'Renowned for its exceptional service and high-quality cuisine, making it a standout option.',
#    'YnnYwfMEeSru_cJ_qKeofw': 'Offers excellent food in a great location, complemented by friendly service.',
#    'ahlZC7XOKN-XJ7P4sPZrRg': 'Good food and service, but slightly less appealing location compared to the top choices.',
#    'J9rMt_V1NX49rU3YUjh_7Q': 'While it has decent offerings, it does not match the overall experience provided by the others.'}},
#  'muNBd72RI-WhHLlwIYaWRA': {'kw': ['service',
#    'food',
#    'restaurant',
#    'price',
#    'seasoning'],
#   'candidate': ['6LgTc7CZlXCd1Pxq3BiVcw',
#    'vVqxGrqt5ALxQjJGnntpKQ',
#    'i5dxKKLe2kJ8WbPUXilPGg',
#    'x44o1_Dw4QsQZRtBJgwZaA',
#    'r1W_Co451x1A1GCMkukMNw'],
#   'explanation': {'6LgTc7CZlXCd1Pxq3BiVcw': 'This restaurant is known for its outstanding service and a menu that beautifully highlights seasoning, making it a top choice for the user.',
#    'vVqxGrqt5ALxQjJGnntpKQ': "This spot offers a great balance of delicious food and good service at reasonable prices, which appeals to the user's preferences.",
#    'i5dxKKLe2kJ8WbPUXilPGg': 'Placed here for its decent food quality and service, but may not shine as brightly in terms of seasoning compared to others above it.',
#    'x44o1_Dw4QsQZRtBJgwZaA': 'While it has good food, the service and overall experience do not match the top-ranked restaurants, reducing its appeal.',
#    'r1W_Co451x1A1GCMkukMNw': "This restaurant falls last due to inconsistent service and flavor profiles that do not align well with the user's seasoning preference."}},
#  '8VAqRRuJy2oaZAVL9QZ49Q': {'kw': ['service',
#    'food',
#    'lunch',
#    'order',
#    'credit cards'],
#   'candidate': ['e7Yr0xwLi73tP2aQ2PjA_w',
#    'gMZsbtlUdmhGOFf_yyDE2Q',
#    'vVUPpLa7C0PCqhWHPDaLfQ',
#    'nCwEzk4Z1lX5PvLEYpbBHw',
#    'DDd3TW3lDvQduqmw-UkrUg'],
#   'explanation': {'e7Yr0xwLi73tP2aQ2PjA_w': 'Known for excellent service and a variety of lunch options, making it a top choice for quick orders.',
#    'gMZsbtlUdmhGOFf_yyDE2Q': 'Offers great food quality with prompt service and accepts credit cards, suitable for lunch takeout.',
#    'vVUPpLa7C0PCqhWHPDaLfQ': 'Provides decent service and food but may have less convenient order options compared to the top two.',
#    'nCwEzk4Z1lX5PvLEYpbBHw': 'Good food but slower service and may not cater to lunch orders as efficiently.',
#    'DDd3TW3lDvQduqmw-UkrUg': 'Although it has good food, it is ranked lower due to less favorable service and order processes for lunch.'}},
#  'tcl9C7lTC6BKq9AlnJFplQ': {'kw': ['service',
#    'food',
#    'drinks',
#    'good service',
#    'view'],
#   'candidate': ['LFknVw6uTIaL-MY_RqkN7g',
#    'J9rMt_V1NX49rU3YUjh_7Q',
#    '0W5UWAcjwGuCJOv8rXGMqw',
#    '6xx2FpMxjwabEHz_t2MiZg',
#    'at7wfECnjgIJi5o7gL8fyQ.'],
#   'explanation': {'LFknVw6uTIaL-MY_RqkN7g': 'This restaurant excels in both service and food quality, with an impressive drinks menu and beautiful views that enhance the dining experience.',
#    'J9rMt_V1NX49rU3YUjh_7Q': 'Noted for its exceptional service and delightful food offerings, this spot also provides a nice ambiance, making it a solid choice for the user’s preferences.',
#    '0W5UWAcjwGuCJOv8rXGMqw': 'While praised for its food, the service has been inconsistent, although it still offers decent drink selections and a pleasant atmosphere.',
#    '6xx2FpMxjwabEHz_t2MiZg': 'Offers good food and drinks but lacks the standout service and scenic views that the user prefers.',
#    'at7wfECnjgIJi5o7gL8fyQ': 'Initially ranked higher, but it has been noted for underwhelming service and food quality, thus lowering its position in this recommendation.'}},
#  'sa2jTUdR3kasSZea_W9RZA': {'kw': ['food',
#    'singapore',
#    'ambience',
#    'rice',
#    'curry'],
#   'candidate': ['K0jxSR_b1Bm4vmjCeSx9qA',
#    'gzBoOo4E1ornEHYod52uew',
#    'U3i7AaegudvpmDL23_wEmQ',
#    'ymAw53bQVppVV7T40fNgRw',
#    'iNVn7TsdKzgrYfRWmWTQOg'],
#   'explanation': {'K0jxSR_b1Bm4vmjCeSx9qA': 'Known for its authentic Singaporean curry dishes and a vibrant atmosphere that enhances the dining experience.',
#    'gzBoOo4E1ornEHYod52uew': 'Offers a fantastic variety of rice-based meals and curries, with a warm ambience perfect for enjoying meals.',
#    'U3i7AaegudvpmDL23_wEmQ': 'A versatile menu featuring local flavors and a cozy setting, though slightly less focused on curry.',
#    'ymAw53bQVppVV7T40fNgRw': 'While it has good food and ambience, it may not offer a strong emphasis on curry or rice dishes.',
#    'iNVn7TsdKzgrYfRWmWTQOg': "Although enjoyable, it ranks lower as it does not specialize in the user's preferred cuisine types."}},
#  'CpGjjYQ8LRBmAn6ARE9qWA': {'kw': ['food',
#    'day',
#    'selection',
#    'mind',
#    'morning'],
#   'candidate': ['KX5KY8fLlMoJMS1NAj0Pvw',
#    'mcFT96dzIsrtGdd9JNmIzw',
#    'Xtr2M_mh9_jOkmpNd_CSCA',
#    '0e30ReHOmL2GzY_3hEy_Ig'],
#   'explanation': {'KX5KY8fLlMoJMS1NAj0Pvw': 'This restaurant is known for its extensive breakfast menu and variety of options, making it ideal for morning dining.',
#    'mcFT96dzIsrtGdd9JNmIzw': 'Offers a good selection of food that is suitable for various tastes, but is slightly less specialized for morning meals.',
#    'Xtr2M_mh9_jOkmpNd_CSCA': 'While it has quality offerings, it lacks the same level of selection for breakfast items as the top two.',
#    '0e30ReHOmL2GzY_3hEy_Ig': 'This restaurant has the least focus on morning dining and is therefore placed last due to user preferences.'}},
#  '-_iULENf28RbqL2k0ja5Xw': {'kw': ['singapore',
#    'rice',
#    'friend',
#    'none',
#    'one'],
#   'candidate': ['Rwzp59f3Ia-v2V8Ku0zZWQ',
#    'NbQH02mMYJ4r1RqvG2FDBA',
#    'ADtSvzL_abKwWPM1EL2yJw'],
#   'explanation': {'Rwzp59f3Ia-v2V8Ku0zZWQ': 'Known for its authentic Singaporean rice dishes and a welcoming vibe, making it ideal for dining with a friend.',
#    'NbQH02mMYJ4r1RqvG2FDBA': 'Offers a variety of rice options with a focus on local flavors, while still providing a friendly environment.',
#    'ADtSvzL_abKwWPM1EL2yJw': 'Although it serves rice dishes, it may not offer as strong a Singaporean flavor or the same level of friendliness as the others.'}},
#  'jV3vIpih0GPmIXOtXqs0VA': {'kw': ['singapore',
#    'rice',
#    'price',
#    'drinks',
#    'flavor'],
#   'candidate': ['DDd3TW3lDvQduqmw-UkrUg',
#    '7LFdimtQU3yrgiKyE53klQ',
#    'NbQH02mMYJ4r1RqvG2FDBA',
#    'pKNDz1tzC5llbengNUz_7w'],
#   'explanation': {'DDd3TW3lDvQduqmw-UkrUg': 'This restaurant excels in authentic Singaporean rice dishes and offers a variety of drinks, aligning well with the user’s preferences.',
#    '7LFdimtQU3yrgiKyE53klQ': "Known for its flavorful rice options, it provides good value and a selection of beverages that appeal to the user's taste.",
#    'NbQH02mMYJ4r1RqvG2FDBA': 'Offers decent rice dishes at reasonable prices, but lacks the drink variety of the top two.',
#    'pKNDz1tzC5llbengNUz_7w': 'While it has some flavor, its offerings are less focused on rice and drinks compared to the others, making it the least preferred option.'}},
#  'WwTYfD8TysD1isAEhSEOoA': {'kw': ['singapore',
#    'star',
#    'great ambiance',
#    'small side',
#    'fast service'],
#   'candidate': ['lJ5YkS5fxC8dcSK4FPtyYQ',
#    'J9rMt_V1NX49rU3YUjh_7Q',
#    'bjL1PC2e9dvjBVewmoXYwQ',
#    'MfspClBaUOwUwj7BBf3xSw'],
#   'explanation': {'lJ5YkS5fxC8dcSK4FPtyYQ': 'Known for its exceptional Singaporean offerings and intimate setting, providing a great ambiance.',
#    'J9rMt_V1NX49rU3YUjh_7Q': "Offers a cozy environment with quick service, appealing to the user's preference for fast dining.",
#    'bjL1PC2e9dvjBVewmoXYwQ': 'Provides a decent menu but lacks the ambiance and quick service the user desires.',
#    'MfspClBaUOwUwj7BBf3xSw': "While it may have good food, it doesn't quite match the request for ambiance and speed."}},
#  'NvVj9v3RvQRZuYwnkRjU2w': {'kw': ['end', 'meal', 'bowl', 'portion', 'menu'],
#   'candidate': ['i5dxKKLe2kJ8WbPUXilPGg',
#    'avrJOt2Kzk7fUpe4D4_DAQ',
#    'x0Pk5Uvy0y63FSzcfmxRpQ',
#    'J9rMt_V1NX49rU3YUjh_7Q',
#    'fY1IkBnRft1KR0O2tqu7pg'],
#   'explanation': {'i5dxKKLe2kJ8WbPUXilPGg': 'Offers hearty bowl meals with a wide variety of choices that cater well to portion preferences.',
#    'avrJOt2Kzk7fUpe4D4_DAQ': 'Known for its flavorful bowls and generous servings that align with user’s desire for a satisfying meal.',
#    'x0Pk5Uvy0y63FSzcfmxRpQ': 'Provides decent bowl options but with a less diverse menu than the top two recommendations.',
#    'J9rMt_V1NX49rU3YUjh_7Q': 'While offering good meals, it falls short in portion size compared to higher-ranked restaurants.',
#    'fY1IkBnRft1KR0O2tqu7pg': "Ranked last due to limited bowl offerings and smaller portions that may not satisfy the user's preferences."}},
#  'MBM7W-xDSEJkYpYPUT6-vA': {'kw': ['meal',
#    'lunch',
#    'things',
#    'breakfast',
#    'favorite'],
#   'candidate': ['Yf4RhB-uTRcZc3l-1icBmw',
#    'TzKx4KbFOzLX0v7F31cSpw',
#    'JG3Yw6z48y6Eyi0DnN19tQ',
#    '4ZOXsBhHx2EzrTwACILK2A'],
#   'explanation': {'Yf4RhB-uTRcZc3l-1icBmw': "This restaurant specializes in a variety of breakfast and brunch options, making it ideal for the user's preference for breakfast and lunch meals.",
#    'TzKx4KbFOzLX0v7F31cSpw': 'A popular spot known for its all-day breakfast, ensuring satisfying meal choices any time of the day.',
#    'JG3Yw6z48y6Eyi0DnN19tQ': 'Offers decent lunch options, but is less focused on breakfast compared to the top two.',
#    '4ZOXsBhHx2EzrTwACILK2A': 'While it has good lunch offerings, it lacks a strong breakfast menu, making it the least suitable option for the user.'}}}

# %%
def save_full_results_to_json(test_users, results, test_users2kw, restaurant_set, re_ranked, explanations, 
                              file_path='./data/Singapore_without_SideIn4.json'):
    output_data = generate_full_results(
        test_users, results, test_users2kw, restaurant_set, re_ranked, explanations
    )
    os.makedirs(os.path.dirname(file_path), exist_ok=True)
    with open(file_path, mode="w", encoding="utf-8") as f:
        json.dump(output_data, f, ensure_ascii=False, indent=4)
    print(f"Full results saved to: {file_path}")

save_full_results_to_json(test_users, results, test_users2kw, restaurant_set, final_results, final_detailed_explanations)
# Out:
# Full results saved to: ./data/Singapore_without_SideIn4.json

# %%
recommended_df = pd.DataFrame({
    "user": test_users,
    "restaurant_names": [", ".join(ranks[:10]) for ranks in final_results]
})

# %%
#Extract groundtruth from test data
user_ground_truth = {}
np2rests = test_data['np2rests']
np2users = test_data['np2users']
for keyword, restaurants in np2rests.items():
    users = np2users.get(keyword, [])
    for user in users:
        user_ground_truth.setdefault(user, set()).update(restaurants.keys())

# %%
user_ground_truth = {u: list(v) for u, v in user_ground_truth.items()}

# %%
def precision_recall_at_k(actual, recommended, k):
    recommended_at_k = recommended[:k]
    hits = len(set(actual) & set(recommended_at_k))
    precision = hits / k    
    recall = hits / len(actual) if actual else 0.0
    return precision, recall

# %%
def average_precision(actual, recommended, k):
    recommended_at_k = recommended[:k]
    score = 0.0
    hits = 0
    for i, r in enumerate(recommended_at_k):
        if r in actual:
            hits += 1
            score += hits / (i + 1)
    return score / min(len(actual), k) if actual else 0.0

# %%
k_values = [5, 10, 20]
precision_scores = {k: [] for k in k_values}
recall_scores    = {k: [] for k in k_values}
avg_precision_scores = []

for _, row in recommended_df.iterrows():
    user = row["user"]
    recommended = row["restaurant_names"].split(", ")
    actual = user_ground_truth.get(user, [])
    
    for k in k_values:
        p, r = precision_recall_at_k(actual, recommended, k)
        precision_scores[k].append(p)
        recall_scores[k].append(r)
    
    # MAP@20
    ap20 = average_precision(actual, recommended, 20)
    avg_precision_scores.append(ap20)

print("Recommendation Quality")
for k in k_values:
    print(f"Precision@{k}: {np.mean(precision_scores[k]):.4f}")
    print(f"Recall@{k}:    {np.mean(recall_scores[k]):.4f}")
MAP = np.mean(avg_precision_scores)
print(f"Mean Average Precision (MAP@20): {MAP:.4f}")

unique_recommended = set()
for names in recommended_df["restaurant_names"]:
    unique_recommended.update(names.split(", "))

all_restaurants = set().union(*[set(d.keys()) for d in test_data['np2rests'].values()])
coverage = len(unique_recommended) / len(all_restaurants) * 100
print(f"Recommendation Coverage: {coverage:.2f}%")
# Out:
# Recommendation Quality
# Precision@5: 0.9076
# Recall@5:    0.0081
# Precision@10: 0.4538
# Recall@10:    0.0081
# Precision@20: 0.2269
# Recall@20:    0.0081
# Mean Average Precision (MAP@20): 0.2251
# Recommendation Coverage: 27.29%
